# %%
import xlrd
import pandas as pd
import numpy as np

# %%
df = pd.read_excel('youth_survey_raw.xlsx')

question_ids = [c for c in df.columns if 'Q' in c]

question_ids
# Out:
# ['Q1',
#  'Q2',
#  'Q3',
#  'Q3x',
#  'Q4_1',
#  'Q4_1_X',
#  'Q4_2',
#  'Q4_2_X',
#  'Q5',
#  'Q6',
#  'Q7',
#  'Q7x',
#  'Q8',
#  'Q8x',
#  'Q9',
#  'Q10',
#  'Q11_1A',
#  'Q11_1B',
#  'Q11_2A',
#  'Q11_2B',
#  'Q11_3A',
#  'Q11_3B',
#  'Q11_4A',
#  'Q11_4B',
#  'Q12',
#  'Q13',
#  'Q14',
#  'Q15',
#  'Q15x',
#  'Q16_1',
#  'Q16_2',
#  'Q16_2_X',
#  'Q16_3',
#  'Q17',
#  'Q18_1',
#  'Q18_2',
#  'Q18_3',
#  'Q19',
#  'Q20_1A',
#  'Q20_1B',
#  'Q20_2A',
#  'Q20_2B',
#  'Q20_3A',
#  'Q20_3B',
#  'Q20_4A',
#  'Q20_4B',
#  'Q20_5A',
#  'Q20_5B',
#  'Q20_6A',
#  'Q20_6B',
#  'Q20_7A',
#  'Q20_7B',
#  'Q21A',
#  'Q21B',
#  'Q21C',
#  'Q21D',
#  'Q22',
#  'Q23A',
#  'Q23B',
#  'Q23C',
#  'Q23D',
#  'Q23E',
#  'Q24',
#  'Q25',
#  'Q25a',
#  'Q26',
#  'Q27_1',
#  'Q27_2',
#  'Q27_2_X',
#  'Q27_3',
#  'Q28',
#  'Q29_1',
#  'Q29_2',
#  'Q29_2_X',
#  'Q29_3',
#  'Q30',
#  'Q31',
#  'Q32',
#  'Q32_X',
#  'Q33',
#  'Q34A',
#  'Q34B',
#  'Q34C',
#  'Q34D',
#  'Q35A',
#  'Q35B',
#  'Q35C',
# ...
