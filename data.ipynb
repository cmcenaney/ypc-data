# %%
import xlrd
import pandas as pd
import numpy as np
import json
import unidecode
from functools import reduce

# %%
def rawDf():
    df = pd.read_excel('input/youth_survey_raw.xlsx')

    # get question ids from columns
    question_ids = [ c for c in df.columns if 'Q' in c ]

    # copy row 0 to column names
    df.columns = df.iloc[0]

    # delete row 0
    df = df.drop(0, axis=0)
    df = df.applymap(str)
    return df

raw_df = rawDf()
raw_df.head()
# Out:
# 0 M1: Questionnaire No Project No  Project Name M2: Governorate M3: District  \
# 1                   79        132  Youth Survey             Ibb    Al-Sabrah
# 2                  101        132  Youth Survey             Ibb  Al-Makhader
# 3                  172        132  Youth Survey           Abyan      Khanfar
# 4                 1107        132  Youth Survey         Shabwah      Jardaan
# 5                 1439        132  Youth Survey         ad-Dali      Qatabah
#
# 0 M7: Urbanity M8: Date of interview M8a: Day of interview  \
# 1        Rural   2017-05-11 00:00:00                   Thu
# 2        Rural   2017-05-12 00:00:00                   Fri
# 3        Rural   2017-05-10 00:00:00                   Wed
# 4        Rural   2017-05-23 00:00:00                   Tue
# 5        Rural   2017-05-10 00:00:00                   Wed
#
# 0 M9: Interview Validation M11b: Date of Auditing            ...             \
# 1            Not validated    2017-05-11 00:00:00            ...
# 2    Accompanied interview    2017-05-12 00:00:00            ...
# 3   Re-contacted by person    2017-05-10 00:00:00            ...
# 4            Not validated    2017-05-23 00:00:00            ...
# 5            Not validated    2017-05-10 00:00:00            ...
#
# 0 Q61_3_X: Other S1: How old are you        S2: What is your marital status?  \
# 1            nan                  17  Single, didn't  not get married before
# 2            nan                  16  Single, didn't  not get married before
# 3            nan                  25                                 Married
# 4            nan                  19                                 Married
# 5            nan                  18  Single, didn't  not get married before
#
# 0 S3: Do you have any children? S4: (If "yes"), How many?  \
# 1                           nan                       nan
# 2                           nan                       nan
# 3                           Yes                         4
# 4                            No                       nan
# 5                           nan                       nan
#
# 0 S5: Including you, how many people, children, above and under 15 live in this household?  \
# 1                                                  6
# 2                                                  6
# 3                                                  6
# 4                                                  9
# 5                                                 13
#
# 0 S6: What is the highest education level you completed?  \
# 1                   Didn't complete secondary school
# 2                      Completed intermediate school
# 3                  Illiterate (Can't read and write)
# 4                         Completed secondary school
# 5                   Didn't complete secondary school
#
# 0 S7: Which one of the folowing income is close to your household monthly income, including all household members incomes live in or out this house?  \
# 1                             20,000 YER- 39,000 YER
# 2                             20,000 YER- 39,000 YER
# 3                               Less than 20,000 YER
# 4                            60,000 YER - 79,000 YER
# 5                            60,000 YER - 79,000 YER
#
# 0 S8: What is your job status today? S11: Gender of respondent
# 1                            Student                      Male
# 2                            Student                      Male
# 3                          Housewife                    Female
# 4                          Housewife                    Female
# 5                            Student                      Male
#
# [5 rows x 191 columns]

# %%
# globals
question_columns = [col.strip() for col in raw_df.columns if col.startswith(('Q'))]
demographic_columns = [col.strip() for col in raw_df.columns if col.startswith(('S'))]

idMap = {
        "abyan":"2",
        "ad-dali":"19",
        "aden":"13",
        "al-baidha":"4",
        "al-mahra":"17",
        "al-mahweet":"16",
        "alhudaida":"8",
        "aljawf":"6",
        "amran":"18",
        "dhamar":"10",
        "hadhramawt":"9",
        "hajja":"7",
        "ibb":"1",
        "lahj":"14",
        "marib":"15",
        "rayma":"20",
        "sana'a city":"3",
        "sana'a":"12",
        "shabwah":"11",
        "taiz":"5"
    }

# %%
def filterDf(df):    
    df_ = df.filter(items=question_columns)
    df_['governorate'] = df['M2: Governorate']
    df_['district'] = df['M3: District']
    df_['urbanity'] = df['M7: Urbanity']
    df_['household_monthly_income'] = df['S7: Which one of the folowing income is close to your household monthly income, including all household members incomes live in or out this house?']
    df_['age'] = df['S1: How old are you']
    df_['marital_status'] = df['S2: What is your marital status?'].apply(lambda x: x.split(', ')[0])
    df_['have_children'] = df['S3: Do you have any children?']
    df_['job_status'] = df['S8: What is your job status today?'].apply(lambda x: x.replace('Unemployed, looking for job', 'Unemployed').replace('Works in his/her own business', 'Self-employed'))
    df_['gender'] = df['S11: Gender of respondent']
    
    return df_

filtered_df = filterDf(raw_df)
filtered_df.head()
# Out:
# 0 Q1: First I would like to ask you about your current situation / family situation. How would you rate it on a scale from 1 to 5?  \
# 1                               Neither bad nor good
# 2                                      It’s very bad
# 3                                      It’s very bad
# 4                               Neither bad nor good
# 5                                 It’s somewhat good
#
# 0 Q2: In general, what do you think about the current situation in Yemen, is it going in the right direction or in the wrong direction?  \
# 1                            In a very bad direction
# 2  3.Not in the right direction, not in the wrong...
# 3                            In a very bad direction
# 4  3.Not in the right direction, not in the wrong...
# 5                            In a very bad direction
#
# 0 Q3: What is your status: Q3x: Other  \
# 1           School student        nan
# 2           School student        nan
# 3         I am a housewife        nan
# 4         I am a housewife        nan
# 5           School student        nan
#
# 0 Q4_1: What are the reasons you had to stop going to school, university, vocational training or lost your job? First answer  \
# 1                                                nan
# 2                                                nan
# 3                                                nan
# 4                                                nan
# 5                                                nan
#
# 0 Q4_1_X :Other  \
# 1           nan
# 2           nan
# 3           nan
# 4           nan
# 5           nan
#
# 0 Q4_2: What are the reasons you had to stop going to school, university, vocational training or lost your job? Second answer  \
# 1                                                nan
# 2                                                nan
# 3                                                nan
# 4                                                nan
# 5                                                nan
#
# 0 Q4_2_X :Other  \
# 1           nan
# 2           nan
# 3           nan
# 4           nan
# 5           nan
#
# 0 Q5: How much time do you spend at school/university/work/vocational training?  \
# 1                                          5-8 hours
# 2                                          1-4 hours
# 3                                                nan
# 4                                                nan
# 5                                          1-4 hours
#
# 0 Q6: How close is the school/university/work/vocational training you attend to your house?  \
# 1                                             0-1 km
# 2                                             0-1 km
# 3                                                nan
# 4                                                nan
# 5                                             0-1 km
#
# 0   ...   Q61_3_X: Other governorate     district urbanity  \
# 1   ...              nan         Ibb    Al-Sabrah    Rural
# 2   ...              nan         Ibb  Al-Makhader    Rural
# 3   ...              nan       Abyan      Khanfar    Rural
# 4   ...              nan     Shabwah      Jardaan    Rural
# 5   ...              nan     ad-Dali      Qatabah    Rural
#
# 0 household_monthly_income age marital_status have_children job_status  gender
# 1   20,000 YER- 39,000 YER  17         Single           nan    Student    Male
# 2   20,000 YER- 39,000 YER  16         Single           nan    Student    Male
# 3     Less than 20,000 YER  25        Married           Yes  Housewife  Female
# 4  60,000 YER - 79,000 YER  19        Married            No  Housewife  Female
# 5  60,000 YER - 79,000 YER  18         Single           nan    Student    Male
#
# [5 rows x 181 columns]

# %%
def mapDf(df):
    df_a_list = []

    for q in question_columns:
        df_a = pd.DataFrame()
        
        q_ = unidecode.unidecode(q)
        qID = q_.split(':')[0]
        q_ = q_.split(':')[1].strip()

        if q_ != 'Other':
            df_a['id'] = df['governorate'].apply(lambda x: idMap[str(x).lower()])
            df_a['governorate'] = df['governorate']
            df_a['district'] = df['district']
            df_a['qID'] = qID
            df_a['question_raw'] = q_
            df_a['answer_raw'] = df[q]
            df_a['urbanity'] = df['urbanity']
            df_a['household_monthly_income'] = df['household_monthly_income']
            df_a['age'] = df['age']
            df_a['marital_status'] = df['marital_status']
            df_a['have_children'] = df['have_children']
            df_a['job_status'] = df['job_status']
            df_a['gender'] = df['gender']

        df_a_list.append(df_a)

    return pd.concat(df_a_list)

mapped_df = mapDf(filtered_df)
mapped_df.head()
# Out:
#    id governorate     district qID  \
# 1   1         Ibb    Al-Sabrah  Q1
# 2   1         Ibb  Al-Makhader  Q1
# 3   2       Abyan      Khanfar  Q1
# 4  11     Shabwah      Jardaan  Q1
# 5  19     ad-Dali      Qatabah  Q1
#
#                                         question_raw            answer_raw  \
# 1  First I would like to ask you about your curre...  Neither bad nor good
# 2  First I would like to ask you about your curre...         It’s very bad
# 3  First I would like to ask you about your curre...         It’s very bad
# 4  First I would like to ask you about your curre...  Neither bad nor good
# 5  First I would like to ask you about your curre...    It’s somewhat good
#
#   urbanity household_monthly_income age marital_status have_children  \
# 1    Rural   20,000 YER- 39,000 YER  17         Single           nan
# 2    Rural   20,000 YER- 39,000 YER  16         Single           nan
# 3    Rural     Less than 20,000 YER  25        Married           Yes
# 4    Rural  60,000 YER - 79,000 YER  19        Married            No
# 5    Rural  60,000 YER - 79,000 YER  18         Single           nan
#
#   job_status  gender
# 1    Student    Male
# 2    Student    Male
# 3  Housewife  Female
# 4  Housewife  Female
# 5    Student    Male

# %%
def calculateDf(df):
    answer_count = df.groupby(['governorate', 'question_raw', 'answer_raw']).transform('count')
    answer_total = df.groupby(['governorate', 'question_raw']).transform('count')

    df['answer_count'] = ""
    df['answer_count'] = answer_count

    df['answer_total'] = ""
    df['answer_total'] = answer_total

    df['answer_pct'] = (df['answer_count'] / df['answer_total'])*100

    df.head()
    return df

calculated_df = calculateDf(mapped_df)
calculated_df.head()
# Out:
#    id governorate     district qID  \
# 1   1         Ibb    Al-Sabrah  Q1
# 2   1         Ibb  Al-Makhader  Q1
# 3   2       Abyan      Khanfar  Q1
# 4  11     Shabwah      Jardaan  Q1
# 5  19     ad-Dali      Qatabah  Q1
#
#                                         question_raw            answer_raw  \
# 1  First I would like to ask you about your curre...  Neither bad nor good
# 2  First I would like to ask you about your curre...         It’s very bad
# 3  First I would like to ask you about your curre...         It’s very bad
# 4  First I would like to ask you about your curre...  Neither bad nor good
# 5  First I would like to ask you about your curre...    It’s somewhat good
#
#   urbanity household_monthly_income age marital_status have_children  \
# 1    Rural   20,000 YER- 39,000 YER  17         Single           nan
# 2    Rural   20,000 YER- 39,000 YER  16         Single           nan
# 3    Rural     Less than 20,000 YER  25        Married           Yes
# 4    Rural  60,000 YER - 79,000 YER  19        Married            No
# 5    Rural  60,000 YER - 79,000 YER  18         Single           nan
#
#   job_status  gender  answer_count  answer_total  answer_pct
# 1    Student    Male            61           170   35.882353
# 2    Student    Male            53           170   31.176471
# 3  Housewife  Female            13            30   43.333333
# 4  Housewife  Female            16            40   40.000000
# 5    Student    Male             9            40   22.500000

# %%
# external D4C data to be joined later
def getTags():
    xls = pd.ExcelFile('input/tagged.xlsx')
    tagged_questions = pd.read_excel(xls, 'questions')
    tagged_answers = pd.read_excel(xls, 'answers')


    df = tagged_questions.merge(tagged_answers, on = ['qID', 'question_raw'], how = 'outer')
    return df

tags_df = getTags()
tags_df
# Out:
#        qID                                       question_raw  \
# 0       Q1  First I would like to ask you about your curre...
# 1       Q1  First I would like to ask you about your curre...
# 2       Q1  First I would like to ask you about your curre...
# 3       Q1  First I would like to ask you about your curre...
# 4       Q1  First I would like to ask you about your curre...
# 5       Q1  First I would like to ask you about your curre...
# 6       Q2  In general, what do you think about the curren...
# 7       Q2  In general, what do you think about the curren...
# 8       Q2  In general, what do you think about the curren...
# 9       Q2  In general, what do you think about the curren...
# 10      Q2  In general, what do you think about the curren...
# 11      Q2  In general, what do you think about the curren...
# 12      Q3                                What is your status
# 13      Q3                                What is your status
# 14      Q3                                What is your status
# 15      Q3                                What is your status
# 16      Q3                                What is your status
# 17      Q3                                What is your status
# 18      Q3                                What is your status
# 19      Q3                                What is your status
# 20      Q3                                What is your status
# 21      Q3                                What is your status
# 22      Q3                                What is your status
# 23      Q3                                What is your status
# 24      Q3                                What is your status
# 25      Q3                                What is your status
# 26      Q3                                What is your status
# 27      Q3                                What is your status
# 28    Q4_1  What are the reasons you had to stop going to ...
# 29    Q4_1  What are the reasons you had to stop going to ...
# ...    ...                                                ...
# 1756  Q62G  How do you evaluate the role that Germany play...
# 1757  Q62G  How do you evaluate the role that Germany play...
# 1758  Q62H  How do you evaluate the role that China plays ...
# 1759  Q62H  How do you evaluate the role that China plays ...
# 1760  Q62H  How do you evaluate the role that China plays ...
# 1761  Q62H  How do you evaluate the role that China plays ...
# 1762  Q62H  How do you evaluate the role that China plays ...
# 1763  Q62H  How do you evaluate the role that China plays ...
# 1764  Q62H  How do you evaluate the role that China plays ...
# 1765  Q62I  How do you evaluate the role that UK plays in ...
# 1766  Q62I  How do you evaluate the role that UK plays in ...
# 1767  Q62I  How do you evaluate the role that UK plays in ...
# 1768  Q62I  How do you evaluate the role that UK plays in ...
# 1769  Q62I  How do you evaluate the role that UK plays in ...
# 1770  Q62I  How do you evaluate the role that UK plays in ...
# 1771  Q62I  How do you evaluate the role that UK plays in ...
# 1772  Q62J  How do you evaluate the role that UAE plays in...
# 1773  Q62J  How do you evaluate the role that UAE plays in...
# 1774  Q62J  How do you evaluate the role that UAE plays in...
# 1775  Q62J  How do you evaluate the role that UAE plays in...
# 1776  Q62J  How do you evaluate the role that UAE plays in...
# 1777  Q62J  How do you evaluate the role that UAE plays in...
# 1778  Q62J  How do you evaluate the role that UAE plays in...
# 1779  Q62K  How do you evaluate the role that Kuwait plays...
# 1780  Q62K  How do you evaluate the role that Kuwait plays...
# 1781  Q62K  How do you evaluate the role that Kuwait plays...
# 1782  Q62K  How do you evaluate the role that Kuwait plays...
# 1783  Q62K  How do you evaluate the role that Kuwait plays...
# 1784  Q62K  How do you evaluate the role that Kuwait plays...
# 1785  Q62K  How do you evaluate the role that Kuwait plays...
#
#                                             question_en  question_ar  \
# 0     How would you rate you and your family's curre...          NaN
# 1     How would you rate you and your family's curre...          NaN
# 2     How would you rate you and your family's curre...          NaN
# 3     How would you rate you and your family's curre...          NaN
# 4     How would you rate you and your family's curre...          NaN
# 5     How would you rate you and your family's curre...          NaN
# 6     Is the situation in Yemen heading in the right...          NaN
# 7     Is the situation in Yemen heading in the right...          NaN
# 8     Is the situation in Yemen heading in the right...          NaN
# 9     Is the situation in Yemen heading in the right...          NaN
# 10    Is the situation in Yemen heading in the right...          NaN
# 11    Is the situation in Yemen heading in the right...          NaN
# 12                      What is your employment status?          NaN
# 13                      What is your employment status?          NaN
# 14                      What is your employment status?          NaN
# 15                      What is your employment status?          NaN
# 16                      What is your employment status?          NaN
# 17                      What is your employment status?          NaN
# 18                      What is your employment status?          NaN
# 19                      What is your employment status?          NaN
# 20                      What is your employment status?          NaN
# 21                      What is your employment status?          NaN
# 22                      What is your employment status?          NaN
# 23                      What is your employment status?          NaN
# 24                      What is your employment status?          NaN
# 25                      What is your employment status?          NaN
# 26                      What is your employment status?          NaN
# 27                      What is your employment status?          NaN
# 28    Why did you stop going to school, university, ...          NaN
# 29    Why did you stop going to school, university, ...          NaN
# ...                                                 ...          ...
# 1756  In your opinion, is Germany playing a positive...          NaN
# 1757  In your opinion, is Germany playing a positive...          NaN
# 1758  In your opinion, is China playing a positive o...          NaN
# 1759  In your opinion, is China playing a positive o...          NaN
# 1760  In your opinion, is China playing a positive o...          NaN
# 1761  In your opinion, is China playing a positive o...          NaN
# 1762  In your opinion, is China playing a positive o...          NaN
# 1763  In your opinion, is China playing a positive o...          NaN
# 1764  In your opinion, is China playing a positive o...          NaN
# 1765  In your opinion, is the UK playing a positive ...          NaN
# 1766  In your opinion, is the UK playing a positive ...          NaN
# 1767  In your opinion, is the UK playing a positive ...          NaN
# 1768  In your opinion, is the UK playing a positive ...          NaN
# 1769  In your opinion, is the UK playing a positive ...          NaN
# 1770  In your opinion, is the UK playing a positive ...          NaN
# 1771  In your opinion, is the UK playing a positive ...          NaN
# 1772  In your opinion, is the United Arab Emirates p...          NaN
# 1773  In your opinion, is the United Arab Emirates p...          NaN
# 1774  In your opinion, is the United Arab Emirates p...          NaN
# 1775  In your opinion, is the United Arab Emirates p...          NaN
# 1776  In your opinion, is the United Arab Emirates p...          NaN
# 1777  In your opinion, is the United Arab Emirates p...          NaN
# 1778  In your opinion, is the United Arab Emirates p...          NaN
# 1779  In your opinion, is Kuwait playing a positive ...          NaN
# 1780  In your opinion, is Kuwait playing a positive ...          NaN
# 1781  In your opinion, is Kuwait playing a positive ...          NaN
# 1782  In your opinion, is Kuwait playing a positive ...          NaN
# 1783  In your opinion, is Kuwait playing a positive ...          NaN
# 1784  In your opinion, is Kuwait playing a positive ...          NaN
# 1785  In your opinion, is Kuwait playing a positive ...          NaN
#
#                  question_tag  question_tag_order question_map question_keep  \
# 0                  daily life                 1.0            y             y
# 1                  daily life                 1.0            y             y
# 2                  daily life                 1.0            y             y
# 3                  daily life                 1.0            y             y
# 4                  daily life                 1.0            y             y
# 5                  daily life                 1.0            y             y
# 6                    politics                 1.0            y             y
# 7                    politics                 1.0            y             y
# 8                    politics                 1.0            y             y
# 9                    politics                 1.0            y             y
# 10                   politics                 1.0            y             y
# 11                   politics                 1.0            y             y
# 12           work & education                 1.0          NaN             y
# 13           work & education                 1.0          NaN             y
# 14           work & education                 1.0          NaN             y
# 15           work & education                 1.0          NaN             y
# 16           work & education                 1.0          NaN             y
# 17           work & education                 1.0          NaN             y
# 18           work & education                 1.0          NaN             y
# 19           work & education                 1.0          NaN             y
# 20           work & education                 1.0          NaN             y
# 21           work & education                 1.0          NaN             y
# 22           work & education                 1.0          NaN             y
# 23           work & education                 1.0          NaN             y
# 24           work & education                 1.0          NaN             y
# 25           work & education                 1.0          NaN             y
# 26           work & education                 1.0          NaN             y
# 27           work & education                 1.0          NaN             y
# 28                        NaN                 NaN          NaN             n
# 29                        NaN                 NaN          NaN             n
# ...                       ...                 ...          ...           ...
# 1756  international relations                 8.0          NaN             y
# 1757  international relations                 8.0          NaN             y
# 1758  international relations                11.0          NaN             y
# 1759  international relations                11.0          NaN             y
# 1760  international relations                11.0          NaN             y
# 1761  international relations                11.0          NaN             y
# 1762  international relations                11.0          NaN             y
# 1763  international relations                11.0          NaN             y
# 1764  international relations                11.0          NaN             y
# 1765  international relations                 6.0          NaN             y
# 1766  international relations                 6.0          NaN             y
# 1767  international relations                 6.0          NaN             y
# 1768  international relations                 6.0          NaN             y
# 1769  international relations                 6.0          NaN             y
# 1770  international relations                 6.0          NaN             y
# 1771  international relations                 6.0          NaN             y
# 1772  international relations                 7.0          NaN             y
# 1773  international relations                 7.0          NaN             y
# 1774  international relations                 7.0          NaN             y
# 1775  international relations                 7.0          NaN             y
# 1776  international relations                 7.0          NaN             y
# 1777  international relations                 7.0          NaN             y
# 1778  international relations                 7.0          NaN             y
# 1779  international relations                 9.0          NaN             y
# 1780  international relations                 9.0          NaN             y
# 1781  international relations                 9.0          NaN             y
# 1782  international relations                 9.0          NaN             y
# 1783  international relations                 9.0          NaN             y
# 1784  international relations                 9.0          NaN             y
# 1785  international relations                 9.0          NaN             y
#
#      question_type  question_scale      aID  \
# 0            scale             5.0    Q1_a1
# 1            scale             5.0    Q1_a2
# 2            scale             5.0    Q1_a3
# 3            scale             5.0    Q1_a4
# 4            scale             5.0    Q1_a5
# 5            scale             5.0    Q1_a6
# 6            scale             5.0    Q2_a1
# 7            scale             5.0    Q2_a2
# 8            scale             5.0    Q2_a3
# 9            scale             5.0    Q2_a4
# 10           scale             5.0    Q2_a5
# 11           scale             5.0    Q2_a6
# 12        category             NaN    Q3_a1
# 13        category             NaN    Q3_a2
# 14        category             NaN    Q3_a3
# 15        category             NaN    Q3_a4
# 16        category             NaN    Q3_a5
# 17        category             NaN    Q3_a6
# 18        category             NaN    Q3_a7
# 19        category             NaN    Q3_a8
# 20        category             NaN    Q3_a9
# 21        category             NaN   Q3_a10
# 22        category             NaN   Q3_a11
# 23        category             NaN   Q3_a12
# 24        category             NaN   Q3_a13
# 25        category             NaN   Q3_a14
# 26        category             NaN   Q3_a15
# 27        category             NaN   Q3_a16
# 28             NaN             NaN  Q4_1_a1
# 29             NaN             NaN  Q4_1_a2
# ...            ...             ...      ...
# 1756         scale             5.0  Q62G_a6
# 1757         scale             5.0  Q62G_a7
# 1758         scale             5.0  Q62H_a1
# 1759         scale             5.0  Q62H_a2
# 1760         scale             5.0  Q62H_a3
# 1761         scale             5.0  Q62H_a4
# 1762         scale             5.0  Q62H_a5
# 1763         scale             5.0  Q62H_a6
# 1764         scale             5.0  Q62H_a7
# 1765         scale             5.0  Q62I_a1
# 1766         scale             5.0  Q62I_a2
# 1767         scale             5.0  Q62I_a3
# 1768         scale             5.0  Q62I_a4
# 1769         scale             5.0  Q62I_a5
# 1770         scale             5.0  Q62I_a6
# 1771         scale             5.0  Q62I_a7
# 1772         scale             5.0  Q62J_a1
# 1773         scale             5.0  Q62J_a2
# 1774         scale             5.0  Q62J_a3
# 1775         scale             5.0  Q62J_a4
# 1776         scale             5.0  Q62J_a5
# 1777         scale             5.0  Q62J_a6
# 1778         scale             5.0  Q62J_a7
# 1779         scale             5.0  Q62K_a1
# 1780         scale             5.0  Q62K_a2
# 1781         scale             5.0  Q62K_a3
# 1782         scale             5.0  Q62K_a4
# 1783         scale             5.0  Q62K_a5
# 1784         scale             5.0  Q62K_a6
# 1785         scale             5.0  Q62K_a7
#
#                                              answer_raw  \
# 0                                            Don't know
# 1                                       It is very good
# 2                                     It's somewhat bad
# 3                                    It's somewhat good
# 4                                         It's very bad
# 5                                  Neither bad nor good
# 6                                            Don't know
# 7     Not in the right direction, not in the wrong d...
# 8                               In a very bad direction
# 9                                In the right direction
# 10                    To some extent in a bad direction
# 11                To some extent in the right direction
# 12                                             Employed
# 13                                     I am a housewife
# 14                                      I am unemployed
# 15    I lost my job because it got destroyed during ...
# 16                I lost my job becauseof other reasons
# 17    I used to go to school, but I can't go to scho...
# 18    I used to go to university, but I can't go to ...
# 19    I used to go to vocational training but I can'...
# 20    I used to go to vocational training, but the i...
# 21    I used to work in my own business but it close...
# 22    I used to work in my own business but it got d...
# 23                            I work in my own business
# 24                                                Other
# 25                                       School student
# 26                                   University student
# 27                                  Vocational training
# 28    Because of the bad living conditions/ to help ...
# 29    Because of war (displacement, stop paying sala...
# ...                                                 ...
# 1756                                               (DK)
# 1757                                               (RF)
# 1758                                      Very negative
# 1759                                                  2
# 1760                                                  3
# 1761                                                  4
# 1762                                      Very positive
# 1763                                               (DK)
# 1764                                               (RF)
# 1765                                      Very negative
# 1766                                                  2
# 1767                                                  3
# 1768                                                  4
# 1769                                      Very positive
# 1770                                               (DK)
# 1771                                               (RF)
# 1772                                      Very negative
# 1773                                                  2
# 1774                                                  3
# 1775                                                  4
# 1776                                      Very positive
# 1777                                               (DK)
# 1778                                               (RF)
# 1779                                      Very negative
# 1780                                                  2
# 1781                                                  3
# 1782                                                  4
# 1783                                      Very positive
# 1784                                               (DK)
# 1785                                               (RF)
#
#                                       answer_en  answer_ar         answer_rank
# 0                                           NaN        NaN                  dk
# 1                                     Very good        NaN                   5
# 2                                           Bad        NaN                   2
# 3                                          Good        NaN                   4
# 4                                      Very bad        NaN                   1
# 5                                       Average        NaN                   3
# 6                                           NaN        NaN                  dk
# 7     Neither the right nor the wrong direction        NaN                   3
# 8                           The wrong direction        NaN                   1
# 9                           The right direction        NaN                   5
# 10               Tending to the wrong direction        NaN                   2
# 11               Tending to the right direction        NaN                   4
# 12                                     Employed        NaN                   2
# 13                                    Housewife        NaN                   4
# 14                                   Unemployed        NaN                   3
# 15                                        Other        NaN                   x
# 16                                        Other        NaN                   x
# 17                                        Other        NaN                   x
# 18                                        Other        NaN                   x
# 19                                        Other        NaN                   x
# 20                                        Other        NaN                   x
# 21                                        Other        NaN                   x
# 22                                        Other        NaN                   x
# 23                                Self-employed        NaN                   6
# 24                                        Other        NaN                   x
# 25                               School student        NaN                   1
# 26                           University student        NaN                   5
# 27                                        Other        NaN                   x
# 28                                          NaN        NaN  removed / repeated
# 29                                          NaN        NaN  removed / repeated
# ...                                         ...        ...                 ...
# 1756                                        NaN        NaN                  dk
# 1757                                        NaN        NaN                   x
# 1758                              Very negative        NaN                   1
# 1759                                   Negative        NaN                   2
# 1760              Neither positive nor negative        NaN                   3
# 1761                                   Positive        NaN                   4
# 1762                              Very positive        NaN                   5
# 1763                                        NaN        NaN                  dk
# 1764                                        NaN        NaN                   x
# 1765                              Very negative        NaN                   1
# 1766                                   Negative        NaN                   2
# 1767              Neither positive nor negative        NaN                   3
# 1768                                   Positive        NaN                   4
# 1769                              Very positive        NaN                   5
# 1770                                        NaN        NaN                  dk
# 1771                                        NaN        NaN                   x
# 1772                              Very negative        NaN                   1
# 1773                                   Negative        NaN                   2
# 1774              Neither positive nor negative        NaN                   3
# 1775                                   Positive        NaN                   4
# 1776                              Very positive        NaN                   5
# 1777                                        NaN        NaN                  dk
# 1778                                        NaN        NaN                   x
# 1779                              Very negative        NaN                   1
# 1780                                   Negative        NaN                   2
# 1781              Neither positive nor negative        NaN                   3
# 1782                                   Positive        NaN                   4
# 1783                              Very positive        NaN                   5
# 1784                                        NaN        NaN                  dk
# 1785                                        NaN        NaN                   x
#
# [1786 rows x 15 columns]

# %%
def mergeDf(raw, tags, kind):
    df = raw.merge(tags, on = ['qID', 'question_raw', 'answer_raw'], how = 'outer')
    
    df = df[df['question_keep'] == 'y']
    mapdf = df[df['question_map'] == 'y']

    df = df[['id','governorate', 'district', 'qID', 'question_raw', 'question_en', 'question_ar', 'question_tag', 'question_tag_order', 'question_type', 'question_map', 'question_scale', 'answer_raw', 'answer_en', 'answer_ar', 'answer_count', 'answer_total', 'answer_pct', 'answer_rank', 'urbanity', 'household_monthly_income', 'age', 'marital_status', 'job_status', 'gender', 'have_children']]
    mapdf = mapdf[['id','governorate', 'district', 'qID', 'question_raw', 'question_en', 'question_ar', 'question_tag', 'question_tag_order', 'question_type', 'question_map', 'question_scale', 'answer_raw', 'answer_en', 'answer_ar', 'answer_count', 'answer_total', 'answer_pct', 'answer_rank', 'urbanity', 'household_monthly_income', 'age', 'marital_status', 'job_status', 'gender', 'have_children']]

    if kind == 'detail':
        return df
    else:
        return mapdf

detail_df = mergeDf(calculated_df, tags_df, 'detail')
map_df = mergeDf(calculated_df, tags_df, 'map')

detail_df.head()
# Out:
#    id governorate        district qID  \
# 0   1         Ibb       Al-Sabrah  Q1
# 1  11     Shabwah         Jardaan  Q1
# 2   9  Hadhramawt  Al-Mukala City  Q1
# 3   1         Ibb       Al-Sabrah  Q1
# 4   1         Ibb   Thee Al-Sufal  Q1
#
#                                         question_raw  \
# 0  First I would like to ask you about your curre...
# 1  First I would like to ask you about your curre...
# 2  First I would like to ask you about your curre...
# 3  First I would like to ask you about your curre...
# 4  First I would like to ask you about your curre...
#
#                                          question_en  question_ar  \
# 0  How would you rate you and your family's curre...          NaN
# 1  How would you rate you and your family's curre...          NaN
# 2  How would you rate you and your family's curre...          NaN
# 3  How would you rate you and your family's curre...          NaN
# 4  How would you rate you and your family's curre...          NaN
#
#   question_tag  question_tag_order question_type      ...      answer_total  \
# 0   daily life                 1.0         scale      ...             170.0
# 1   daily life                 1.0         scale      ...              40.0
# 2   daily life                 1.0         scale      ...              80.0
# 3   daily life                 1.0         scale      ...             170.0
# 4   daily life                 1.0         scale      ...             170.0
#
#    answer_pct answer_rank urbanity  household_monthly_income  age  \
# 0   35.882353           3    Rural    20,000 YER- 39,000 YER   17
# 1   40.000000           3    Rural   60,000 YER - 79,000 YER   19
# 2   21.250000           3    Urban                      (DK)   16
# 3   35.882353           3    Rural   40,000 YER - 59,000 YER   25
# 4   35.882353           3    Rural   60,000 YER - 79,000 YER   17
#
#    marital_status  job_status  gender have_children
# 0          Single     Student    Male           nan
# 1         Married   Housewife  Female            No
# 2          Single     Student  Female           nan
# 3           Widow   Housewife  Female           Yes
# 4          Single     Student  Female           nan
#
# [5 rows x 26 columns]

# %%
def cleanDf(df):
    df_ = df[['id', 'governorate', 'question_tag', 'question_tag_order', 'question_map', 'question_raw', 'question_en', 'question_ar', 'answer_raw', 'answer_en', 'answer_ar', 'answer_rank', 'answer_count', 'answer_pct']]
    df_ = df_.sort_values(['id', 'question_tag', 'question_tag_order', 'answer_rank'])
    df_ = df_.drop_duplicates()
    df_ = df_[df_['answer_rank'] != 'removed / repeated']
    df_ = df_[df_['id'].notnull()]
    df_ = df_.fillna('')
    
    return df_

detail_clean_df = cleanDf(detail_df)
detail_clean_df.head()
# Out:
#        id governorate question_tag  question_tag_order question_map  \
# 117714  1         Ibb  basic needs                 1.0            y
# 118434  1         Ibb  basic needs                 1.0            y
# 117786  1         Ibb  basic needs                 1.0            y
# 116976  1         Ibb  basic needs                 1.0            y
# 115804  1         Ibb  basic needs                 1.0            y
#
#                                              question_raw  \
# 117714  Please tell me if Adequate  shelter/housing is...
# 118434  Please tell me if Adequate  shelter/housing is...
# 117786  Please tell me if Adequate  shelter/housing is...
# 116976  Please tell me if Adequate  shelter/housing is...
# 115804  Please tell me if Adequate  shelter/housing is...
#
#                                               question_en question_ar  \
# 117714  Does your family have access to adequate shelt...
# 118434  Does your family have access to adequate shelt...
# 117786  Does your family have access to adequate shelt...
# 116976  Does your family have access to adequate shelt...
# 115804  Does your family have access to adequate shelt...
#
#                     answer_raw       answer_en answer_ar answer_rank  \
# 117714    Not available at all       No, never                     1
# 118434  Somewhat not available  Only sometimes                     2
# 117786      Somewhat available   Sometimes yes                     3
# 116976               Available             Yes                     4
# 115804          Very available     Yes, always                     5
#
#         answer_count  answer_pct
# 117714           1.0    0.588235
# 118434           7.0    4.117647
# 117786          42.0   24.705882
# 116976          39.0   22.941176
# 115804          81.0   47.647059

# %%
q62_df = pd.read_csv('input/q62.csv')
q62_df['id'] = q62_df['id'].apply(lambda x: str(x))
q62_df = q62_df.fillna('')

detail_plus_q62 = pd.concat([q62_df, detail_clean_df])

detail_plus_q62.head()
# Out:
#   id  governorate             question_tag  question_tag_order question_map  \
# 0  1          Ibb  international relations                10.0
# 1  2        Abyan  international relations                10.0
# 2  3  Sana'a City  international relations                10.0
# 3  4   al-Baydha'  international relations                10.0
# 4  5         Taiz  international relations                10.0
#
#                                         question_raw  \
# 0  How do you evaluate the role that Oman plays i...
# 1  How do you evaluate the role that Oman plays i...
# 2  How do you evaluate the role that Oman plays i...
# 3  How do you evaluate the role that Oman plays i...
# 4  How do you evaluate the role that Oman plays i...
#
#                                          question_en question_ar  \
# 0  In your opinion, is Oman playing a positive or...
# 1  In your opinion, is Oman playing a positive or...
# 2  In your opinion, is Oman playing a positive or...
# 3  In your opinion, is Oman playing a positive or...
# 4  In your opinion, is Oman playing a positive or...
#
#       answer_raw      answer_en answer_ar answer_rank  answer_count  \
# 0  Very negative  Very negative                     1          16.0
# 1  Very negative  Very negative                     1           5.0
# 2  Very negative  Very negative                     1          61.0
# 3  Very negative  Very negative                     1           0.0
# 4  Very negative  Very negative                     1          53.0
#
#    answer_pct
# 0    9.411765
# 1   16.666667
# 2   43.571429
# 3    0.000000
# 4   27.894737

# %%
detail_plus_q62.to_csv('output/ypc_edit.csv', index=False)

# %%
# into json format for charting
question_cols = ['id', 'governorate', 'question_tag', 'question_tag_order', 'question_raw', 'question_en', 'question_ar']
answer_cols = ['answer_raw', 'answer_en', 'answer_ar', 'answer_rank', 'answer_count', 'answer_pct']

def build_question_dict(df_):
    result = {
        c: df_[c].values[0] for c in question_cols
    }

    result['values'] = []
    for _, row in df_.groupby('answer_raw'):

        result['values'].append({
            c: row[c].values[0] for c in answer_cols        
        })
        
    return result


for key, df_ in detail_plus_q62.groupby( ['id'] ):
    
    results = []
    for id_, df__ in df_.groupby('question_raw'):
        
        results.append( build_question_dict(df__) )
    
    with open('output/gov/gov_'+key+'.json', 'w') as outfile:
        print ('output/gov/gov_'+key+'.json')
        json.dump(results, outfile)
# Out:
# output/gov/gov_1.json
# output/gov/gov_10.json
# output/gov/gov_11.json
# output/gov/gov_12.json
# output/gov/gov_13.json
# output/gov/gov_14.json
# output/gov/gov_15.json
# output/gov/gov_16.json
# output/gov/gov_17.json
# output/gov/gov_18.json
# output/gov/gov_19.json
# output/gov/gov_2.json
# output/gov/gov_20.json
# output/gov/gov_3.json
# output/gov/gov_4.json
# output/gov/gov_5.json
# output/gov/gov_6.json
# output/gov/gov_7.json
# output/gov/gov_8.json
# output/gov/gov_9.json

# %%
def getMapData(df):
    return df[df['question_map'] == 'y']
    
map_df = getMapData(detail_plus_q62)
map_df.to_csv('output/map.csv', index=False)
map_df.head()


# {
#     "id": 16,
#     "gov": "al-Mahweet",
#     "rank": 0.0825,
#     "question_en": "How much time do you spend at school, university, work or vocational training per day?",
#     "question_ar": "كم من الوقت تقضيه خلال اليوم داخل مؤسسة تعليمية، مدرستك / الجامعة / العمل / التدريب المهني؟",
#     "tag": "education",
#     "scale_upper_en": "more",
#     "scale_lower_en": "less",
#     "scale_upper_ar": "أكثر",
#     "scale_lower_ar": "أقل"
#   },
# Out:
#     id  governorate             question_tag  question_tag_order question_map  \
# 120  1          Ibb  international relations                 2.0            y
# 121  2        Abyan  international relations                 2.0            y
# 122  3  Sana'a City  international relations                 2.0            y
# 123  4   al-Baydha'  international relations                 2.0            y
# 124  5         Taiz  international relations                 2.0            y
#
#                                           question_raw  \
# 120  How do you evaluate the role that US plays in ...
# 121  How do you evaluate the role that US plays in ...
# 122  How do you evaluate the role that US plays in ...
# 123  How do you evaluate the role that US plays in ...
# 124  How do you evaluate the role that US plays in ...
#
#                                            question_en question_ar  \
# 120  In your opinion, is the US playing a positive ...
# 121  In your opinion, is the US playing a positive ...
# 122  In your opinion, is the US playing a positive ...
# 123  In your opinion, is the US playing a positive ...
# 124  In your opinion, is the US playing a positive ...
#
#         answer_raw      answer_en answer_ar answer_rank  answer_count  \
# 120  Very negative  Very negative                     1         108.0
# 121  Very negative  Very negative                     1           4.0
# 122  Very negative  Very negative                     1         129.0
# 123  Very negative  Very negative                     1          13.0
# 124  Very negative  Very negative                     1          78.0
#
#      answer_pct
# 120   63.529412
# 121   13.333333
# 122   92.142857
# 123   32.500000
# 124   41.052632

# %%
question_cols = ['id', 'governorate', 'question_tag', 'question_tag_order', 'question_raw', 'question_en', 'question_ar']
answer_cols = ['answer_raw', 'answer_en', 'answer_ar', 'answer_rank', 'answer_count', 'answer_pct']

def build_question_dict(df_):
    result = {
        c: df_[c].values[0] for c in question_cols
    }

    result['values'] = []
    
    answer_ranks = []
    answer_pcts = []
    
    for _, row in df_.groupby('answer_raw'):
        
            
        if row['answer_rank'].values[0] != 'dk':
            answer_ranks.append(int(row['answer_rank'].values[0]))
            answer_pcts.append(row['answer_pct'].values[0])
    

   
    print (answer_ranks)
    print (answer_pcts)
    
    max_rank = max(answer_ranks)
    print ('max:', max_rank)
    
    multiplier = (100/max_rank) / 100
    print ('multiplier:', multiplier)
    
    multiply_func = lambda x: (x * multiplier) / 100
    
    multiplied_list = list(map(multiply_func, answer_ranks))
    print ('multi:', multiplied_list)
    
    answer_pct_multiplied = [a*b for a,b in zip(answer_pcts, multiplied_list)]
    
    rank = sum(answer_pct_multiplied)
    print ('rank:', rank)
    
    
#     rank_max = max(answer_ranks)
#     rank_div = (100/rank_max) / 100
    
#     print (rank_max, rank_div)
    
#     multiplier = lambda x: (x*rank_div)/100
    
#     multiplier_list = list(map(multiplier, answer_ranks))
#     print (multiplier_list)
    
    
#     print (answer_pcts)
    
#     answer_pct_multiplied = [a*b for a,b in zip(answer_pcts, multiplier_list)]
    
#     print (answer_pct_multiplied)
#     print (sum(answer_pct_multiplied))

# #         for c in answer_cols:
# #             print ()
# #             print (c)
# #             print (row[c])

# #         result['values'].append({
# #             c: row[c].values[0] for c in answer_cols        
# #         })
        
#     return result


for key, df_ in map_df.groupby( ['id'] ):
    
    results = []
    for id_, df__ in df_.groupby('question_raw'):
        
    
        print ()
        print (key)
        print (id_)
        results.append( build_question_dict(df__) )
    
    
   
    
#     with open('output/gov/gov_'+key+'.json', 'w') as outfile:
#         print ('output/gov/gov_'+key+'.json')
#         json.dump(results, outfile)
# Out:
# 1
# According to your opinion, Are Political Parties active in your area in a positive way, active in a negative way, neither positive nor negative, not active at all?
# [1, 5, 4, 2]
# [15.294117647058824, 1.1764705882352942, 21.764705882352942, 21.176470588235293]
# max: 5
# multiplier: 0.2
# multi: [0.002, 0.01, 0.008, 0.004]
# rank: 0.3011764705882353
#
# 1
# According to your opinion, Are Religious groups active in your area in a positive way, active in a negative way, neither positive nor negative, not active at all?
# [1, 5, 4, 2]
# [0.5882352941176471, 8.235294117647058, 17.058823529411764, 3.5294117647058822]
# max: 5
# multiplier: 0.2
# multi: [0.002, 0.01, 0.008, 0.004]
# rank: 0.23411764705882354
#
# 1
# According to your opinion, Are Tribal leaders active in your area in a positive way, active in a negative way, neither positive nor negative, not active at all?
# [1, 5, 4, 2]
# [3.5294117647058822, 14.117647058823529, 31.176470588235293, 1.7647058823529411]
# max: 5
# multiplier: 0.2
# multi: [0.002, 0.01, 0.008, 0.004]
# rank: 0.4047058823529412
#
# 1
# According to your opinion, Is Local Council  active in your area in a positive way, active in a negative way, neither positive nor negative, not active at all?
# [1, 5, 4, 2]
# [19.411764705882355, 3.5294117647058822, 20.588235294117645, 11.76470588235294]
# max: 5
# multiplier: 0.2
# multi: [0.002, 0.01, 0.008, 0.004]
# rank: 0.2858823529411765
#
# 1
# According to your opinion, Is NGO/CSO active in your area in a positive way, active in a negative way, neither positive nor negative, not active at all?
# [1, 5, 4, 2]
# [0.5882352941176471, 2.3529411764705883, 15.88235294117647, 12.941176470588237]
# max: 5
# multiplier: 0.2
# multi: [0.002, 0.01, 0.008, 0.004]
# rank: 0.20352941176470585
#
# 1
# According to your opinion, Is Police active in your area in a positive way, active in a negative way, neither positive nor negative, not active at all?
# [1, 5, 4, 2]
# [10.588235294117647, 12.941176470588237, 38.82352941176471, 4.705882352941177]
# max: 5
# multiplier: 0.2
# multi: [0.002, 0.01, 0.008, 0.004]
# rank: 0.48
#
# 1
# According to your opinion, how available are these services and products in your area? Education
# [2, 1, 3, 4]
# [19.411764705882355, 1.1764705882352942, 45.88235294117647, 33.52941176470588]
# max: 4
# multiplier: 0.25
# multi: [0.005, 0.0025, 0.0075, 0.01]
# rank: 0.7794117647058824
#
# 1
# According to your opinion, how available are these services and products in your area? Electricity
# [2, 1, 3, 4]
# [12.352941176470589, 67.64705882352942, 14.705882352941178, 1.1764705882352942]
# max: 4
# multiplier: 0.25
# multi: [0.005, 0.0025, 0.0075, 0.01]
# rank: 0.3529411764705883
#
# 1
# According to your opinion, how available are these services and products in your area? Health Care
# [2, 1, 3, 4]
# [45.294117647058826, 20.0, 27.647058823529413, 5.88235294117647]
# max: 4
# multiplier: 0.25
# multi: [0.005, 0.0025, 0.0075, 0.01]
# rank: 0.5426470588235295
#
# 1
# According to your opinion, how available are these services and products in your area? Water
# [2, 1, 3, 4]
# [34.11764705882353, 1.1764705882352942, 41.17647058823529, 23.52941176470588]
# max: 4
# multiplier: 0.25
# multi: [0.005, 0.0025, 0.0075, 0.01]
# rank: 0.7176470588235293
#
# 1
# Do you have internet access?
# [1, 2]
# [65.29411764705883, 34.705882352941174]
# max: 2
# multiplier: 0.5
# multi: [0.005, 0.01]
# rank: 0.6735294117647059
#
# 1
# First I would like to ask you about your current situation / family situation. How would you rate it on a scale from 1 to 5?
# [5, 3]
# [4.117647058823529, 35.88235294117647]
# max: 5
# multiplier: 0.2
# multi: [0.01, 0.006000000000000001]
# rank: 0.2564705882352942
#
# 1
# How do evaluate the general security situation in your area?
# [2, 3, 4, 1, 5]
# [14.117647058823529, 22.941176470588236, 36.470588235294116, 5.294117647058823, 21.176470588235293]
# max: 5
# multiplier: 0.2
# multi: [0.004, 0.006000000000000001, 0.008, 0.002, 0.01]
# rank: 0.7082352941176471
#
# 1
# How do you evaluate the role that EU plays in Yemen?
# [2, 3, 4, 1, 5]
# [14.70588235, 22.35294118, 3.529411765, 25.29411765, 1.764705882]
# max: 5
# multiplier: 0.2
# multi: [0.004, 0.006000000000000001, 0.008, 0.002, 0.01]
# rank: 0.28941176472
#
# 1
# How do you evaluate the role that Iran plays in Yemen?
# [2, 3, 4, 1, 5]
# [11.17647059, 14.11764706, 5.882352941000001, 57.05882353, 7.058823529]
# max: 5
# multiplier: 0.2
# multi: [0.004, 0.006000000000000001, 0.008, 0.002, 0.01]
# rank: 0.36117647059800007
#
# 1
# How do you evaluate the role that KSA plays in Yemen?
# [2, 3, 4, 1, 5]
# [9.411764706, 7.058823529, 5.294117647, 66.47058824, 9.411764706]
# max: 5
# multiplier: 0.2
# multi: [0.004, 0.006000000000000001, 0.008, 0.002, 0.01]
# rank: 0.34941176471400004
#
# 1
# How do you evaluate the role that US plays in Yemen?
# [2, 3, 4, 1, 5]
# [11.17647059, 7.647058824, 7.058823529, 63.52941176, 4.705882353]
# max: 5
# multiplier: 0.2
# multi: [0.004, 0.006000000000000001, 0.008, 0.002, 0.01]
# rank: 0.321176470586
#
# 1
# How much do you believe Yemen should be divided into regions?
# [2, 3, 4]
# [24.705882352941178, 8.235294117647058, 1.7647058823529411]
# max: 4
# multiplier: 0.25
# multi: [0.005, 0.0075, 0.01]
# rank: 0.20294117647058824
#
# 1
# How much do you believe south Yemen should be independent?
# [2, 3, 4]
# [21.764705882352942, 8.823529411764707, 1.7647058823529411]
# max: 4
# multiplier: 0.25
# multi: [0.005, 0.0075, 0.01]
# rank: 0.1926470588235294
#
# 1
# I will list a number of reasons that can lead to conflict "Political Difference" (Conflicts in the neighborhood)
# [2, 3, 4, 1, 5]
# [16.470588235294116, 30.0, 28.823529411764703, 1.7647058823529411, 22.35294117647059]
# max: 5
# multiplier: 0.2
# multi: [0.004, 0.006000000000000001, 0.008, 0.002, 0.01]
# rank: 0.703529411764706
#
# 1
# I will list a number of reasons that can lead to conflict "Religious Differences" (Conflicts in the neighborhood)
# [2, 3, 4, 1, 5]
# [26.47058823529412, 24.705882352941178, 15.294117647058824, 27.647058823529413, 3.5294117647058822]
# max: 5
# multiplier: 0.2
# multi: [0.004, 0.006000000000000001, 0.008, 0.002, 0.01]
# rank: 0.4670588235294118
#
# 1
# I will list read a number of places where conflicts take place, please let me know how often conflicts take place (Conflicts in the neighborhood)
# [2, 3, 4, 1, 5]
# [35.294117647058826, 35.88235294117647, 16.470588235294116, 1.1764705882352942, 11.176470588235295]
# max: 5
# multiplier: 0.2
# multi: [0.004, 0.006000000000000001, 0.008, 0.002, 0.01]
# rank: 0.6023529411764706
#
# 1
# In general, what do you think about the current situation in Yemen, is it going in the right direction or in the wrong direction?
# [1, 2, 4]
# [33.52941176470588, 34.11764705882353, 2.3529411764705883]
# max: 4
# multiplier: 0.25
# multi: [0.0025, 0.005, 0.01]
# rank: 0.27794117647058825
#
# 1
# On a scale ranging from 1 to 5 in which "1" means "always very unsafe" and "5" means "always very safe", how safe do you personally feel?
# [5, 1, 4, 2, 3]
# [35.294117647058826, 7.0588235294117645, 27.647058823529413, 9.411764705882353, 20.588235294117645]
# max: 5
# multiplier: 0.2
# multi: [0.01, 0.002, 0.008, 0.004, 0.006000000000000001]
# rank: 0.7494117647058823
#
# 1
# Please tell me if Adequate  shelter/housing is available or not for your family
# [4, 1, 3, 2, 5]
# [22.941176470588236, 0.5882352941176471, 24.705882352941178, 4.117647058823529, 47.647058823529406]
# max: 5
# multiplier: 0.2
# multi: [0.008, 0.002, 0.006000000000000001, 0.004, 0.01]
# rank: 0.8258823529411765
#
# 1
# Thinking about the last year, have there been times when your family didn't have enough food for all household members?
# [1, 2]
# [71.17647058823529, 24.705882352941178]
# max: 2
# multiplier: 0.5
# multi: [0.005, 0.01]
# rank: 0.6029411764705883
#
# 10
# According to your opinion, Are Political Parties active in your area in a positive way, active in a negative way, neither positive nor negative, not active at all?
# [1, 5, 4, 2]
# [27.0, 9.0, 21.0, 28.999999999999996]
# max: 5
# multiplier: 0.2
# multi: [0.002, 0.01, 0.008, 0.004]
# rank: 0.428
#
# 10
# According to your opinion, Are Religious groups active in your area in a positive way, active in a negative way, neither positive nor negative, not active at all?
# [1, 5, 4, 2]
# [3.0, 18.0, 4.0, 1.0]
# max: 5
# multiplier: 0.2
# multi: [0.002, 0.01, 0.008, 0.004]
# rank: 0.222
#
# 10
# According to your opinion, Are Tribal leaders active in your area in a positive way, active in a negative way, neither positive nor negative, not active at all?
# [1, 5, 4, 2]
# [18.0, 41.0, 24.0, 3.0]
# max: 5
# multiplier: 0.2
# multi: [0.002, 0.01, 0.008, 0.004]
# rank: 0.6500000000000001
#
# 10
# According to your opinion, Is Local Council  active in your area in a positive way, active in a negative way, neither positive nor negative, not active at all?
# [1, 5, 4, 2]
# [22.0, 17.0, 22.0, 30.0]
# max: 5
# multiplier: 0.2
# multi: [0.002, 0.01, 0.008, 0.004]
# rank: 0.51
#
# 10
# According to your opinion, Is NGO/CSO active in your area in a positive way, active in a negative way, neither positive nor negative, not active at all?
# [1, 5, 4, 2]
# [20.0, 18.0, 4.0, 8.0]
# max: 5
# multiplier: 0.2
# multi: [0.002, 0.01, 0.008, 0.004]
# rank: 0.28400000000000003
#
# 10
# According to your opinion, Is Police active in your area in a positive way, active in a negative way, neither positive nor negative, not active at all?
# [1, 5, 4, 2]
# [6.0, 31.0, 18.0, 14.000000000000002]
# max: 5
# multiplier: 0.2
# multi: [0.002, 0.01, 0.008, 0.004]
# rank: 0.522
#
# 10
# According to your opinion, how available are these services and products in your area? Education
# [2, 3, 4]
# [25.0, 68.0, 7.000000000000001]
# max: 4
# multiplier: 0.25
# multi: [0.005, 0.0075, 0.01]
# rank: 0.7050000000000001
#
# 10
# According to your opinion, how available are these services and products in your area? Electricity
# [2, 1, 3, 4]
# [1.0, 86.0, 8.0, 3.0]
# max: 4
# multiplier: 0.25
# multi: [0.005, 0.0025, 0.0075, 0.01]
# rank: 0.31000000000000005
#
# 10
# According to your opinion, how available are these services and products in your area? Health Care
# [2, 1, 3, 4]
# [50.0, 18.0, 25.0, 7.000000000000001]
# max: 4
# multiplier: 0.25
# multi: [0.005, 0.0025, 0.0075, 0.01]
# rank: 0.5525
#
# 10
# According to your opinion, how available are these services and products in your area? Water
# [2, 3, 4]
# [34.0, 38.0, 28.000000000000004]
# max: 4
# multiplier: 0.25
# multi: [0.005, 0.0075, 0.01]
# rank: 0.735
#
# 10
# Do you have internet access?
# [1, 2]
# [94.0, 6.0]
# max: 2
# multiplier: 0.5
# multi: [0.005, 0.01]
# rank: 0.53
#
# 10
# First I would like to ask you about your current situation / family situation. How would you rate it on a scale from 1 to 5?
# [5, 3]
# [3.0, 17.0]
# max: 5
# multiplier: 0.2
# multi: [0.01, 0.006000000000000001]
# rank: 0.132
#
# 10
# How do evaluate the general security situation in your area?
# [3, 4, 1, 5]
# [2.0, 32.0, 1.0, 65.0]
# max: 5
# multiplier: 0.2
# multi: [0.006000000000000001, 0.008, 0.002, 0.01]
# rank: 0.92
#
# 10
# How do you evaluate the role that EU plays in Yemen?
# [2, 3, 4, 1, 5]
# [8.0, 5.0, 4.0, 65.0, 1.0]
# max: 5
# multiplier: 0.2
# multi: [0.004, 0.006000000000000001, 0.008, 0.002, 0.01]
# rank: 0.234
#
# 10
# How do you evaluate the role that Iran plays in Yemen?
# [2, 3, 4, 1, 5]
# [14.0, 13.0, 3.0, 62.0, 7.0]
# max: 5
# multiplier: 0.2
# multi: [0.004, 0.006000000000000001, 0.008, 0.002, 0.01]
# rank: 0.35200000000000004
#
# 10
# How do you evaluate the role that KSA plays in Yemen?
# [2, 3, 4, 1, 5]
# [0.0, 8.0, 9.0, 66.0, 16.0]
# max: 5
# multiplier: 0.2
# multi: [0.004, 0.006000000000000001, 0.008, 0.002, 0.01]
# rank: 0.41200000000000003
#
# 10
# How do you evaluate the role that US plays in Yemen?
# [2, 3, 4, 1, 5]
# [3.0, 3.0, 7.0, 87.0, 0.0]
# max: 5
# multiplier: 0.2
# multi: [0.004, 0.006000000000000001, 0.008, 0.002, 0.01]
# rank: 0.26
#
# 10
# How much do you believe Yemen should be divided into regions?
# [2, 3, 4, 5]
# [8.0, 4.0, 5.0, 3.0]
# max: 5
# multiplier: 0.2
# multi: [0.004, 0.006000000000000001, 0.008, 0.01]
# rank: 0.126
#
# 10
# How much do you believe south Yemen should be independent?
# [2, 3]
# [7.000000000000001, 3.0]
# max: 3
# multiplier: 0.33333333333333337
# multi: [0.006666666666666667, 0.01]
# rank: 0.07666666666666667
#
# 10
# I will list a number of reasons that can lead to conflict "Political Difference" (Conflicts in the neighborhood)
# [2, 3, 4, 1, 5]
# [36.0, 25.0, 20.0, 14.000000000000002, 4.0]
# max: 5
# multiplier: 0.2
# multi: [0.004, 0.006000000000000001, 0.008, 0.002, 0.01]
# rank: 0.5220000000000001
#
# 10
# I will list a number of reasons that can lead to conflict "Religious Differences" (Conflicts in the neighborhood)
# [2, 3, 4, 1, 5]
# [27.0, 12.0, 5.0, 54.0, 2.0]
# max: 5
# multiplier: 0.2
# multi: [0.004, 0.006000000000000001, 0.008, 0.002, 0.01]
# rank: 0.34800000000000003
#
# 10
# I will list read a number of places where conflicts take place, please let me know how often conflicts take place (Conflicts in the neighborhood)
# [2, 3, 4, 1, 5]
# [26.0, 26.0, 26.0, 11.0, 11.0]
# max: 5
# multiplier: 0.2
# multi: [0.004, 0.006000000000000001, 0.008, 0.002, 0.01]
# rank: 0.6000000000000001
#
# 10
# In general, what do you think about the current situation in Yemen, is it going in the right direction or in the wrong direction?
# [1, 5, 2, 4]
# [62.0, 2.0, 14.000000000000002, 6.0]
# max: 5
# multiplier: 0.2
# multi: [0.002, 0.01, 0.004, 0.008]
# rank: 0.248
#
# 10
# On a scale ranging from 1 to 5 in which "1" means "always very unsafe" and "5" means "always very safe", how safe do you personally feel?
# [5, 1, 4, 3]
# [96.0, 1.0, 1.0, 2.0]
# max: 5
# multiplier: 0.2
# multi: [0.01, 0.002, 0.008, 0.006000000000000001]
# rank: 0.982
#
# 10
# Please tell me if Adequate  shelter/housing is available or not for your family
# [4, 1, 3, 2, 5]
# [8.0, 1.0, 25.0, 1.0, 65.0]
# max: 5
# multiplier: 0.2
# multi: [0.008, 0.002, 0.006000000000000001, 0.004, 0.01]
# rank: 0.8700000000000001
#
# 10
# Thinking about the last year, have there been times when your family didn't have enough food for all household members?
# [1, 2]
# [57.99999999999999, 42.0]
# max: 2
# multiplier: 0.5
# multi: [0.005, 0.01]
# rank: 0.71
#
# 11
# According to your opinion, Are Political Parties active in your area in a positive way, active in a negative way, neither positive nor negative, not active at all?
# [1, 4, 2]
# [47.5, 10.0, 5.0]
# max: 4
# multiplier: 0.25
# multi: [0.0025, 0.01, 0.005]
# rank: 0.24375
#
# 11
# According to your opinion, Are Religious groups active in your area in a positive way, active in a negative way, neither positive nor negative, not active at all?
# [1, 5]
# [15.0, 17.5]
# max: 5
# multiplier: 0.2
# multi: [0.002, 0.01]
# rank: 0.20500000000000002
#
# 11
# According to your opinion, Are Tribal leaders active in your area in a positive way, active in a negative way, neither positive nor negative, not active at all?
# [1, 5, 4, 2]
# [27.500000000000004, 30.0, 22.5, 5.0]
# max: 5
# multiplier: 0.2
# multi: [0.002, 0.01, 0.008, 0.004]
# rank: 0.5549999999999999
#
# 11
# According to your opinion, Is Local Council  active in your area in a positive way, active in a negative way, neither positive nor negative, not active at all?
# [1, 5, 4, 2]
# [20.0, 2.5, 15.0, 10.0]
# max: 5
# multiplier: 0.2
# multi: [0.002, 0.01, 0.008, 0.004]
# rank: 0.225
#
# 11
# According to your opinion, Is NGO/CSO active in your area in a positive way, active in a negative way, neither positive nor negative, not active at all?
# [1, 5, 4, 2]
# [5.0, 40.0, 15.0, 2.5]
# max: 5
# multiplier: 0.2
# multi: [0.002, 0.01, 0.008, 0.004]
# rank: 0.54
#
# 11
# According to your opinion, Is Police active in your area in a positive way, active in a negative way, neither positive nor negative, not active at all?
# [1, 4, 2]
# [2.5, 5.0, 40.0]
# max: 4
# multiplier: 0.25
# multi: [0.0025, 0.01, 0.005]
# rank: 0.25625000000000003
#
# 11
# According to your opinion, how available are these services and products in your area? Education
# [2, 3]
# [32.5, 67.5]
# max: 3
# multiplier: 0.33333333333333337
# multi: [0.006666666666666667, 0.01]
# rank: 0.8916666666666667
#
# 11
# According to your opinion, how available are these services and products in your area? Electricity
# [2, 1]
# [25.0, 65.0]
# max: 2
# multiplier: 0.5
# multi: [0.01, 0.005]
# rank: 0.575
#
# 11
# According to your opinion, how available are these services and products in your area? Health Care
# [2, 1]
# [37.5, 57.49999999999999]
# max: 2
# multiplier: 0.5
# multi: [0.01, 0.005]
# rank: 0.6625
#
# 11
# According to your opinion, how available are these services and products in your area? Water
# [2, 1, 3, 4]
# [50.0, 5.0, 37.5, 7.5]
# max: 4
# multiplier: 0.25
# multi: [0.005, 0.0025, 0.0075, 0.01]
# rank: 0.6187499999999999
#
# 11
# Do you have internet access?
# [1, 2]
# [60.0, 40.0]
# max: 2
# multiplier: 0.5
# multi: [0.005, 0.01]
# rank: 0.7
#
# 11
# First I would like to ask you about your current situation / family situation. How would you rate it on a scale from 1 to 5?
# [5, 3]
# [2.5, 40.0]
# max: 5
# multiplier: 0.2
# multi: [0.01, 0.006000000000000001]
# rank: 0.26500000000000007
#
# 11
# How do evaluate the general security situation in your area?
# [2, 3, 4, 1, 5]
# [7.5, 32.5, 32.5, 10.0, 12.5]
# max: 5
# multiplier: 0.2
# multi: [0.004, 0.006000000000000001, 0.008, 0.002, 0.01]
# rank: 0.63
#
# 11
# How do you evaluate the role that EU plays in Yemen?
# [2, 3, 4, 1, 5]
# [5.0, 15.0, 2.5, 7.5, 0.0]
# max: 5
# multiplier: 0.2
# multi: [0.004, 0.006000000000000001, 0.008, 0.002, 0.01]
# rank: 0.14500000000000002
#
# 11
# How do you evaluate the role that Iran plays in Yemen?
# [2, 3, 4, 1, 5]
# [0.0, 0.0, 0.0, 72.5, 0.0]
# max: 5
# multiplier: 0.2
# multi: [0.004, 0.006000000000000001, 0.008, 0.002, 0.01]
# rank: 0.145
#
# 11
# How do you evaluate the role that KSA plays in Yemen?
# [2, 3, 4, 1, 5]
# [0.0, 10.0, 20.0, 2.5, 52.5]
# max: 5
# multiplier: 0.2
# multi: [0.004, 0.006000000000000001, 0.008, 0.002, 0.01]
# rank: 0.75
#
# 11
# How do you evaluate the role that US plays in Yemen?
# [2, 3, 4, 1, 5]
# [10.0, 5.0, 5.0, 50.0, 5.0]
# max: 5
# multiplier: 0.2
# multi: [0.004, 0.006000000000000001, 0.008, 0.002, 0.01]
# rank: 0.26
#
# 11
# How much do you believe Yemen should be divided into regions?
# [3, 4, 5]
# [12.5, 2.5, 40.0]
# max: 5
# multiplier: 0.2
# multi: [0.006000000000000001, 0.008, 0.01]
# rank: 0.49500000000000005
#
# 11
# How much do you believe south Yemen should be independent?
# [2, 3, 4, 5]
# [5.0, 7.5, 5.0, 62.5]
# max: 5
# multiplier: 0.2
# multi: [0.004, 0.006000000000000001, 0.008, 0.01]
# rank: 0.73
#
# 11
# I will list a number of reasons that can lead to conflict "Political Difference" (Conflicts in the neighborhood)
# [2, 3, 4, 1, 5]
# [7.5, 17.5, 15.0, 5.0, 32.5]
# max: 5
# multiplier: 0.2
# multi: [0.004, 0.006000000000000001, 0.008, 0.002, 0.01]
# rank: 0.5900000000000001
#
# 11
# I will list a number of reasons that can lead to conflict "Religious Differences" (Conflicts in the neighborhood)
# [2, 3, 1]
# [22.5, 7.5, 47.5]
# max: 3
# multiplier: 0.33333333333333337
# multi: [0.006666666666666667, 0.01, 0.0033333333333333335]
# rank: 0.3833333333333334
#
# 11
# I will list read a number of places where conflicts take place, please let me know how often conflicts take place (Conflicts in the neighborhood)
# [2, 3, 4, 1, 5]
# [22.5, 37.5, 7.5, 7.5, 5.0]
# max: 5
# multiplier: 0.2
# multi: [0.004, 0.006000000000000001, 0.008, 0.002, 0.01]
# rank: 0.44000000000000006
#
# 11
# In general, what do you think about the current situation in Yemen, is it going in the right direction or in the wrong direction?
# [1, 5, 2, 4]
# [40.0, 2.5, 30.0, 5.0]
# max: 5
# multiplier: 0.2
# multi: [0.002, 0.01, 0.004, 0.008]
# rank: 0.265
#
# 11
# On a scale ranging from 1 to 5 in which "1" means "always very unsafe" and "5" means "always very safe", how safe do you personally feel?
# [5, 1, 4, 2, 3]
# [40.0, 7.5, 15.0, 15.0, 22.5]
# max: 5
# multiplier: 0.2
# multi: [0.01, 0.002, 0.008, 0.004, 0.006000000000000001]
# rank: 0.73
#
# 11
# Please tell me if Adequate  shelter/housing is available or not for your family
# [4, 1, 3, 2, 5]
# [22.5, 2.5, 37.5, 5.0, 32.5]
# max: 5
# multiplier: 0.2
# multi: [0.008, 0.002, 0.006000000000000001, 0.004, 0.01]
# rank: 0.7550000000000001
#
# 11
# Thinking about the last year, have there been times when your family didn't have enough food for all household members?
# [1, 2]
# [70.0, 30.0]
# max: 2
# multiplier: 0.5
# multi: [0.005, 0.01]
# rank: 0.65
#
# 12
# According to your opinion, Are Political Parties active in your area in a positive way, active in a negative way, neither positive nor negative, not active at all?
# [4]
# [1.4285714285714286]
# max: 4
# multiplier: 0.25
# multi: [0.01]
# rank: 0.014285714285714287
#
# 12
# According to your opinion, Are Religious groups active in your area in a positive way, active in a negative way, neither positive nor negative, not active at all?
# [1]
# [1.4285714285714286]
# max: 1
# multiplier: 1.0
# multi: [0.01]
# rank: 0.014285714285714287
#
# 12
# According to your opinion, Are Tribal leaders active in your area in a positive way, active in a negative way, neither positive nor negative, not active at all?
# [5, 4, 2]
# [2.857142857142857, 1.4285714285714286, 4.285714285714286]
# max: 5
# multiplier: 0.2
# multi: [0.01, 0.008, 0.004]
# rank: 0.05714285714285715
#
# 12
# According to your opinion, Is Local Council  active in your area in a positive way, active in a negative way, neither positive nor negative, not active at all?
# [2]
# [2.857142857142857]
# max: 2
# multiplier: 0.5
# multi: [0.01]
# rank: 0.028571428571428574
#
# 12
# According to your opinion, Is NGO/CSO active in your area in a positive way, active in a negative way, neither positive nor negative, not active at all?
# [5, 4]
# [7.142857142857142, 4.285714285714286]
# max: 5
# multiplier: 0.2
# multi: [0.01, 0.008]
# rank: 0.1057142857142857
#
# 12
# According to your opinion, Is Police active in your area in a positive way, active in a negative way, neither positive nor negative, not active at all?
# [4]
# [4.285714285714286]
# max: 4
# multiplier: 0.25
# multi: [0.01]
# rank: 0.04285714285714286
#
# 12
# According to your opinion, how available are these services and products in your area? Education
# [2, 1, 3, 4]
# [27.142857142857142, 11.428571428571429, 34.285714285714285, 27.142857142857142]
# max: 4
# multiplier: 0.25
# multi: [0.005, 0.0025, 0.0075, 0.01]
# rank: 0.6928571428571428
#
# 12
# According to your opinion, how available are these services and products in your area? Electricity
# [2, 1, 3]
# [4.285714285714286, 92.85714285714286, 1.4285714285714286]
# max: 3
# multiplier: 0.33333333333333337
# multi: [0.006666666666666667, 0.0033333333333333335, 0.01]
# rank: 0.3523809523809524
#
# 12
# According to your opinion, how available are these services and products in your area? Health Care
# [2, 1, 3, 4]
# [11.428571428571429, 31.428571428571427, 34.285714285714285, 22.857142857142858]
# max: 4
# multiplier: 0.25
# multi: [0.005, 0.0025, 0.0075, 0.01]
# rank: 0.6214285714285714
#
# 12
# According to your opinion, how available are these services and products in your area? Water
# [2, 1, 3, 4]
# [58.57142857142858, 5.714285714285714, 17.142857142857142, 18.571428571428573]
# max: 4
# multiplier: 0.25
# multi: [0.005, 0.0025, 0.0075, 0.01]
# rank: 0.6214285714285714
#
# 12
# Do you have internet access?
# [1, 2]
# [55.714285714285715, 44.285714285714285]
# max: 2
# multiplier: 0.5
# multi: [0.005, 0.01]
# rank: 0.7214285714285714
#
# 12
# First I would like to ask you about your current situation / family situation. How would you rate it on a scale from 1 to 5?
# [5, 3]
# [5.714285714285714, 38.57142857142858]
# max: 5
# multiplier: 0.2
# multi: [0.01, 0.006000000000000001]
# rank: 0.28857142857142865
#
# 12
# How do evaluate the general security situation in your area?
# [2, 3, 4, 1, 5]
# [2.857142857142857, 5.714285714285714, 25.71428571428571, 2.857142857142857, 62.857142857142854]
# max: 5
# multiplier: 0.2
# multi: [0.004, 0.006000000000000001, 0.008, 0.002, 0.01]
# rank: 0.8857142857142857
#
# 12
# How do you evaluate the role that EU plays in Yemen?
# [2, 3, 4, 1, 5]
# [0.0, 11.42857143, 0.0, 61.42857143, 0.0]
# max: 5
# multiplier: 0.2
# multi: [0.004, 0.006000000000000001, 0.008, 0.002, 0.01]
# rank: 0.19142857144000003
#
# 12
# How do you evaluate the role that Iran plays in Yemen?
# [2, 3, 4, 1, 5]
# [8.571428571, 0.0, 0.0, 77.14285714, 0.0]
# max: 5
# multiplier: 0.2
# multi: [0.004, 0.006000000000000001, 0.008, 0.002, 0.01]
# rank: 0.188571428564
#
# 12
# How do you evaluate the role that KSA plays in Yemen?
# [2, 3, 4, 1, 5]
# [1.428571429, 0.0, 0.0, 90.0, 0.0]
# max: 5
# multiplier: 0.2
# multi: [0.004, 0.006000000000000001, 0.008, 0.002, 0.01]
# rank: 0.185714285716
#
# 12
# How do you evaluate the role that US plays in Yemen?
# [2, 3, 4, 1, 5]
# [0.0, 1.428571429, 0.0, 92.85714286, 0.0]
# max: 5
# multiplier: 0.2
# multi: [0.004, 0.006000000000000001, 0.008, 0.002, 0.01]
# rank: 0.194285714294
#
# 12
# How much do you believe Yemen should be divided into regions?
# [2]
# [1.4285714285714286]
# max: 2
# multiplier: 0.5
# multi: [0.01]
# rank: 0.014285714285714287
#
# 12
# I will list a number of reasons that can lead to conflict "Political Difference" (Conflicts in the neighborhood)
# [2, 3, 4, 1, 5]
# [1.4285714285714286, 10.0, 42.857142857142854, 28.57142857142857, 11.428571428571429]
# max: 5
# multiplier: 0.2
# multi: [0.004, 0.006000000000000001, 0.008, 0.002, 0.01]
# rank: 0.5800000000000001
#
# 12
# I will list a number of reasons that can lead to conflict "Religious Differences" (Conflicts in the neighborhood)
# [2, 3, 4, 1, 5]
# [2.857142857142857, 4.285714285714286, 7.142857142857142, 70.0, 1.4285714285714286]
# max: 5
# multiplier: 0.2
# multi: [0.004, 0.006000000000000001, 0.008, 0.002, 0.01]
# rank: 0.24857142857142858
#
# 12
# I will list read a number of places where conflicts take place, please let me know how often conflicts take place (Conflicts in the neighborhood)
# [2, 3, 4, 1, 5]
# [28.57142857142857, 12.857142857142856, 18.571428571428573, 31.428571428571427, 8.571428571428571]
# max: 5
# multiplier: 0.2
# multi: [0.004, 0.006000000000000001, 0.008, 0.002, 0.01]
# rank: 0.48857142857142866
#
# 12
# In general, what do you think about the current situation in Yemen, is it going in the right direction or in the wrong direction?
# [1, 2, 4]
# [82.85714285714286, 5.714285714285714, 5.714285714285714]
# max: 4
# multiplier: 0.25
# multi: [0.0025, 0.005, 0.01]
# rank: 0.29285714285714287
#
# 12
# On a scale ranging from 1 to 5 in which "1" means "always very unsafe" and "5" means "always very safe", how safe do you personally feel?
# [5, 4, 2]
# [87.14285714285714, 8.571428571428571, 2.857142857142857]
# max: 5
# multiplier: 0.2
# multi: [0.01, 0.008, 0.004]
# rank: 0.9514285714285715
#
# 12
# Please tell me if Adequate  shelter/housing is available or not for your family
# [4, 1, 3, 2, 5]
# [20.0, 1.4285714285714286, 5.714285714285714, 7.142857142857142, 65.71428571428571]
# max: 5
# multiplier: 0.2
# multi: [0.008, 0.002, 0.006000000000000001, 0.004, 0.01]
# rank: 0.8828571428571429
#
# 12
# Thinking about the last year, have there been times when your family didn't have enough food for all household members?
# [1, 2]
# [84.28571428571429, 15.714285714285714]
# max: 2
# multiplier: 0.5
# multi: [0.005, 0.01]
# rank: 0.5785714285714286
#
# 13
# According to your opinion, Are Political Parties active in your area in a positive way, active in a negative way, neither positive nor negative, not active at all?
# [1, 5, 4, 2]
# [30.0, 2.0, 4.0, 2.0]
# max: 5
# multiplier: 0.2
# multi: [0.002, 0.01, 0.008, 0.004]
# rank: 0.12
#
# 13
# According to your opinion, Are Religious groups active in your area in a positive way, active in a negative way, neither positive nor negative, not active at all?
# [1, 5, 4, 2]
# [2.0, 34.0, 8.0, 2.0]
# max: 5
# multiplier: 0.2
# multi: [0.002, 0.01, 0.008, 0.004]
# rank: 0.41600000000000004
#
# 13
# According to your opinion, Are Tribal leaders active in your area in a positive way, active in a negative way, neither positive nor negative, not active at all?
# [5, 4, 2]
# [6.0, 4.0, 2.0]
# max: 5
# multiplier: 0.2
# multi: [0.01, 0.008, 0.004]
# rank: 0.1
#
# 13
# According to your opinion, Is Local Council  active in your area in a positive way, active in a negative way, neither positive nor negative, not active at all?
# [1, 5, 4, 2]
# [12.0, 18.0, 22.0, 2.0]
# max: 5
# multiplier: 0.2
# multi: [0.002, 0.01, 0.008, 0.004]
# rank: 0.388
#
# 13
# According to your opinion, Is NGO/CSO active in your area in a positive way, active in a negative way, neither positive nor negative, not active at all?
# [1, 5, 4, 2]
# [2.0, 18.0, 8.0, 4.0]
# max: 5
# multiplier: 0.2
# multi: [0.002, 0.01, 0.008, 0.004]
# rank: 0.264
#
# 13
# According to your opinion, Is Police active in your area in a positive way, active in a negative way, neither positive nor negative, not active at all?
# [5, 4]
# [88.0, 6.0]
# max: 5
# multiplier: 0.2
# multi: [0.01, 0.008]
# rank: 0.928
#
# 13
# According to your opinion, how available are these services and products in your area? Education
# [2, 3, 4]
# [2.0, 12.0, 86.0]
# max: 4
# multiplier: 0.25
# multi: [0.005, 0.0075, 0.01]
# rank: 0.96
#
# 13
# According to your opinion, how available are these services and products in your area? Electricity
# [2, 3]
# [88.0, 12.0]
# max: 3
# multiplier: 0.33333333333333337
# multi: [0.006666666666666667, 0.01]
# rank: 0.7066666666666667
#
# 13
# According to your opinion, how available are these services and products in your area? Health Care
# [2, 1, 3, 4]
# [22.0, 6.0, 52.0, 18.0]
# max: 4
# multiplier: 0.25
# multi: [0.005, 0.0025, 0.0075, 0.01]
# rank: 0.6950000000000001
#
# 13
# According to your opinion, how available are these services and products in your area? Water
# [2, 3, 4]
# [46.0, 44.0, 10.0]
# max: 4
# multiplier: 0.25
# multi: [0.005, 0.0075, 0.01]
# rank: 0.6599999999999999
#
# 13
# Do you have internet access?
# [1, 2]
# [32.0, 66.0]
# max: 2
# multiplier: 0.5
# multi: [0.005, 0.01]
# rank: 0.8200000000000001
#
# 13
# First I would like to ask you about your current situation / family situation. How would you rate it on a scale from 1 to 5?
# [5, 3]
# [6.0, 34.0]
# max: 5
# multiplier: 0.2
# multi: [0.01, 0.006000000000000001]
# rank: 0.264
#
# 13
# How do evaluate the general security situation in your area?
# [2, 3, 4, 1, 5]
# [6.0, 10.0, 32.0, 4.0, 48.0]
# max: 5
# multiplier: 0.2
# multi: [0.004, 0.006000000000000001, 0.008, 0.002, 0.01]
# rank: 0.8280000000000001
#
# 13
# How do you evaluate the role that EU plays in Yemen?
# [2, 3, 4, 1, 5]
# [8.0, 28.0, 18.0, 16.0, 2.0]
# max: 5
# multiplier: 0.2
# multi: [0.004, 0.006000000000000001, 0.008, 0.002, 0.01]
# rank: 0.39600000000000013
#
# 13
# How do you evaluate the role that Iran plays in Yemen?
# [2, 3, 4, 1, 5]
# [0.0, 0.0, 2.0, 88.0, 0.0]
# max: 5
# multiplier: 0.2
# multi: [0.004, 0.006000000000000001, 0.008, 0.002, 0.01]
# rank: 0.192
#
# 13
# How do you evaluate the role that KSA plays in Yemen?
# [2, 3, 4, 1, 5]
# [0.0, 0.0, 0.0, 2.0, 94.0]
# max: 5
# multiplier: 0.2
# multi: [0.004, 0.006000000000000001, 0.008, 0.002, 0.01]
# rank: 0.9440000000000001
#
# 13
# How do you evaluate the role that US plays in Yemen?
# [2, 3, 4, 1, 5]
# [4.0, 32.0, 18.0, 14.0, 4.0]
# max: 5
# multiplier: 0.2
# multi: [0.004, 0.006000000000000001, 0.008, 0.002, 0.01]
# rank: 0.42000000000000004
#
# 13
# How much do you believe Yemen should be divided into regions?
# [2, 3, 4, 5]
# [10.0, 16.0, 2.0, 2.0]
# max: 5
# multiplier: 0.2
# multi: [0.004, 0.006000000000000001, 0.008, 0.01]
# rank: 0.17200000000000001
#
# 13
# How much do you believe south Yemen should be independent?
# [3, 4, 5]
# [2.0, 10.0, 72.0]
# max: 5
# multiplier: 0.2
# multi: [0.006000000000000001, 0.008, 0.01]
# rank: 0.8119999999999999
#
# 13
# I will list a number of reasons that can lead to conflict "Political Difference" (Conflicts in the neighborhood)
# [2, 3, 4, 1, 5]
# [14.000000000000002, 16.0, 8.0, 44.0, 6.0]
# max: 5
# multiplier: 0.2
# multi: [0.004, 0.006000000000000001, 0.008, 0.002, 0.01]
# rank: 0.36400000000000005
#
# 13
# I will list a number of reasons that can lead to conflict "Religious Differences" (Conflicts in the neighborhood)
# [2, 3, 4, 1]
# [2.0, 8.0, 4.0, 80.0]
# max: 4
# multiplier: 0.25
# multi: [0.005, 0.0075, 0.01, 0.0025]
# rank: 0.31
#
# 13
# I will list read a number of places where conflicts take place, please let me know how often conflicts take place (Conflicts in the neighborhood)
# [2, 3, 4, 1, 5]
# [22.0, 26.0, 6.0, 34.0, 6.0]
# max: 5
# multiplier: 0.2
# multi: [0.004, 0.006000000000000001, 0.008, 0.002, 0.01]
# rank: 0.42000000000000004
#
# 13
# In general, what do you think about the current situation in Yemen, is it going in the right direction or in the wrong direction?
# [1, 5, 2, 4]
# [32.0, 6.0, 28.000000000000004, 4.0]
# max: 5
# multiplier: 0.2
# multi: [0.002, 0.01, 0.004, 0.008]
# rank: 0.268
#
# 13
# On a scale ranging from 1 to 5 in which "1" means "always very unsafe" and "5" means "always very safe", how safe do you personally feel?
# [5, 4, 2, 3]
# [68.0, 20.0, 6.0, 2.0]
# max: 5
# multiplier: 0.2
# multi: [0.01, 0.008, 0.004, 0.006000000000000001]
# rank: 0.8760000000000001
#
# 13
# Please tell me if Adequate  shelter/housing is available or not for your family
# [4, 3, 2, 5]
# [20.0, 18.0, 6.0, 56.00000000000001]
# max: 5
# multiplier: 0.2
# multi: [0.008, 0.006000000000000001, 0.004, 0.01]
# rank: 0.8520000000000001
#
# 13
# Thinking about the last year, have there been times when your family didn't have enough food for all household members?
# [1, 2]
# [84.0, 14.000000000000002]
# max: 2
# multiplier: 0.5
# multi: [0.005, 0.01]
# rank: 0.56
#
# 14
# According to your opinion, Are Political Parties active in your area in a positive way, active in a negative way, neither positive nor negative, not active at all?
# [1, 4, 2]
# [10.0, 5.0, 20.0]
# max: 4
# multiplier: 0.25
# multi: [0.0025, 0.01, 0.005]
# rank: 0.17500000000000002
#
# 14
# According to your opinion, Are Religious groups active in your area in a positive way, active in a negative way, neither positive nor negative, not active at all?
# [1, 5, 2]
# [1.6666666666666667, 16.666666666666664, 1.6666666666666667]
# max: 5
# multiplier: 0.2
# multi: [0.002, 0.01, 0.004]
# rank: 0.17666666666666664
#
# 14
# According to your opinion, Are Tribal leaders active in your area in a positive way, active in a negative way, neither positive nor negative, not active at all?
# [5, 4, 2]
# [71.66666666666667, 10.0, 5.0]
# max: 5
# multiplier: 0.2
# multi: [0.01, 0.008, 0.004]
# rank: 0.8166666666666667
#
# 14
# According to your opinion, Is Local Council  active in your area in a positive way, active in a negative way, neither positive nor negative, not active at all?
# [1, 4, 2]
# [11.666666666666666, 3.3333333333333335, 43.333333333333336]
# max: 4
# multiplier: 0.25
# multi: [0.0025, 0.01, 0.005]
# rank: 0.2791666666666667
#
# 14
# According to your opinion, Is NGO/CSO active in your area in a positive way, active in a negative way, neither positive nor negative, not active at all?
# [1, 4, 2]
# [6.666666666666667, 1.6666666666666667, 5.0]
# max: 4
# multiplier: 0.25
# multi: [0.0025, 0.01, 0.005]
# rank: 0.058333333333333334
#
# 14
# According to your opinion, Is Police active in your area in a positive way, active in a negative way, neither positive nor negative, not active at all?
# [1, 5, 4, 2]
# [11.666666666666666, 13.333333333333334, 6.666666666666667, 30.0]
# max: 5
# multiplier: 0.2
# multi: [0.002, 0.01, 0.008, 0.004]
# rank: 0.33
#
# 14
# According to your opinion, how available are these services and products in your area? Education
# [2, 3, 4]
# [13.333333333333334, 66.66666666666666, 18.333333333333332]
# max: 4
# multiplier: 0.25
# multi: [0.005, 0.0075, 0.01]
# rank: 0.7499999999999999
#
# 14
# According to your opinion, how available are these services and products in your area? Electricity
# [2, 1, 3]
# [20.0, 76.66666666666667, 3.3333333333333335]
# max: 3
# multiplier: 0.33333333333333337
# multi: [0.006666666666666667, 0.0033333333333333335, 0.01]
# rank: 0.4222222222222223
#
# 14
# According to your opinion, how available are these services and products in your area? Health Care
# [2, 1, 3]
# [28.333333333333332, 61.66666666666667, 8.333333333333332]
# max: 3
# multiplier: 0.33333333333333337
# multi: [0.006666666666666667, 0.0033333333333333335, 0.01]
# rank: 0.4777777777777778
#
# 14
# According to your opinion, how available are these services and products in your area? Water
# [2, 1, 3, 4]
# [43.333333333333336, 10.0, 31.666666666666664, 15.0]
# max: 4
# multiplier: 0.25
# multi: [0.005, 0.0025, 0.0075, 0.01]
# rank: 0.6291666666666667
#
# 14
# Do you have internet access?
# [1, 2]
# [85.0, 15.0]
# max: 2
# multiplier: 0.5
# multi: [0.005, 0.01]
# rank: 0.575
#
# 14
# First I would like to ask you about your current situation / family situation. How would you rate it on a scale from 1 to 5?
# [3]
# [8.333333333333332]
# max: 3
# multiplier: 0.33333333333333337
# multi: [0.01]
# rank: 0.08333333333333333
#
# 14
# How do evaluate the general security situation in your area?
# [2, 4, 1, 5]
# [1.6666666666666667, 6.666666666666667, 1.6666666666666667, 90.0]
# max: 5
# multiplier: 0.2
# multi: [0.004, 0.008, 0.002, 0.01]
# rank: 0.9633333333333334
#
# 14
# How do you evaluate the role that EU plays in Yemen?
# [2, 3, 4, 1, 5]
# [5.0, 8.333333332999999, 0.0, 21.66666667, 0.0]
# max: 5
# multiplier: 0.2
# multi: [0.004, 0.006000000000000001, 0.008, 0.002, 0.01]
# rank: 0.113333333338
#
# 14
# How do you evaluate the role that Iran plays in Yemen?
# [2, 3, 4, 1, 5]
# [0.0, 0.0, 0.0, 66.66666667, 0.0]
# max: 5
# multiplier: 0.2
# multi: [0.004, 0.006000000000000001, 0.008, 0.002, 0.01]
# rank: 0.13333333334
#
# 14
# How do you evaluate the role that KSA plays in Yemen?
# [2, 3, 4, 1, 5]
# [0.0, 8.333333332999999, 10.0, 13.33333333, 56.66666667]
# max: 5
# multiplier: 0.2
# multi: [0.004, 0.006000000000000001, 0.008, 0.002, 0.01]
# rank: 0.723333333358
#
# 14
# How do you evaluate the role that US plays in Yemen?
# [2, 3, 4, 1, 5]
# [0.0, 0.0, 0.0, 56.66666667, 3.333333333]
# max: 5
# multiplier: 0.2
# multi: [0.004, 0.006000000000000001, 0.008, 0.002, 0.01]
# rank: 0.14666666667
#
# 14
# How much do you believe Yemen should be divided into regions?
# [2, 3, 4, 5]
# [6.666666666666667, 1.6666666666666667, 3.3333333333333335, 5.0]
# max: 5
# multiplier: 0.2
# multi: [0.004, 0.006000000000000001, 0.008, 0.01]
# rank: 0.11333333333333334
#
# 14
# How much do you believe south Yemen should be independent?
# [2, 3, 5]
# [5.0, 5.0, 26.666666666666668]
# max: 5
# multiplier: 0.2
# multi: [0.004, 0.006000000000000001, 0.01]
# rank: 0.31666666666666665
#
# 14
# I will list a number of reasons that can lead to conflict "Political Difference" (Conflicts in the neighborhood)
# [2, 3, 4, 1, 5]
# [6.666666666666667, 13.333333333333334, 3.3333333333333335, 31.666666666666664, 26.666666666666668]
# max: 5
# multiplier: 0.2
# multi: [0.004, 0.006000000000000001, 0.008, 0.002, 0.01]
# rank: 0.4633333333333334
#
# 14
# I will list a number of reasons that can lead to conflict "Religious Differences" (Conflicts in the neighborhood)
# [2, 3, 4, 1, 5]
# [6.666666666666667, 5.0, 5.0, 55.00000000000001, 10.0]
# max: 5
# multiplier: 0.2
# multi: [0.004, 0.006000000000000001, 0.008, 0.002, 0.01]
# rank: 0.3066666666666667
#
# 14
# I will list read a number of places where conflicts take place, please let me know how often conflicts take place (Conflicts in the neighborhood)
# [2, 3, 4, 1, 5]
# [13.333333333333334, 20.0, 10.0, 20.0, 25.0]
# max: 5
# multiplier: 0.2
# multi: [0.004, 0.006000000000000001, 0.008, 0.002, 0.01]
# rank: 0.5433333333333333
#
# 14
# In general, what do you think about the current situation in Yemen, is it going in the right direction or in the wrong direction?
# [1, 5, 2, 4]
# [11.666666666666666, 3.3333333333333335, 8.333333333333332, 28.333333333333332]
# max: 5
# multiplier: 0.2
# multi: [0.002, 0.01, 0.004, 0.008]
# rank: 0.31666666666666665
#
# 14
# On a scale ranging from 1 to 5 in which "1" means "always very unsafe" and "5" means "always very safe", how safe do you personally feel?
# [5, 4, 2]
# [90.0, 6.666666666666667, 3.3333333333333335]
# max: 5
# multiplier: 0.2
# multi: [0.01, 0.008, 0.004]
# rank: 0.9666666666666667
#
# 14
# Please tell me if Adequate  shelter/housing is available or not for your family
# [4, 1, 3, 2, 5]
# [13.333333333333334, 5.0, 30.0, 28.333333333333332, 23.333333333333332]
# max: 5
# multiplier: 0.2
# multi: [0.008, 0.002, 0.006000000000000001, 0.004, 0.01]
# rank: 0.6433333333333333
#
# 14
# Thinking about the last year, have there been times when your family didn't have enough food for all household members?
# [1, 2]
# [38.333333333333336, 58.333333333333336]
# max: 2
# multiplier: 0.5
# multi: [0.005, 0.01]
# rank: 0.775
#
# 15
# According to your opinion, Are Political Parties active in your area in a positive way, active in a negative way, neither positive nor negative, not active at all?
# [1, 5, 4]
# [25.0, 20.0, 15.0]
# max: 5
# multiplier: 0.2
# multi: [0.002, 0.01, 0.008]
# rank: 0.37
#
# 15
# According to your opinion, Are Religious groups active in your area in a positive way, active in a negative way, neither positive nor negative, not active at all?
# [5, 4]
# [85.0, 5.0]
# max: 5
# multiplier: 0.2
# multi: [0.01, 0.008]
# rank: 0.89
#
# 15
# According to your opinion, Are Tribal leaders active in your area in a positive way, active in a negative way, neither positive nor negative, not active at all?
# [1, 5, 4]
# [10.0, 40.0, 20.0]
# max: 5
# multiplier: 0.2
# multi: [0.002, 0.01, 0.008]
# rank: 0.5800000000000001
#
# 15
# According to your opinion, Is Local Council  active in your area in a positive way, active in a negative way, neither positive nor negative, not active at all?
# [1, 5, 4]
# [10.0, 25.0, 15.0]
# max: 5
# multiplier: 0.2
# multi: [0.002, 0.01, 0.008]
# rank: 0.39
#
# 15
# According to your opinion, Is NGO/CSO active in your area in a positive way, active in a negative way, neither positive nor negative, not active at all?
# [1, 5, 4]
# [10.0, 15.0, 10.0]
# max: 5
# multiplier: 0.2
# multi: [0.002, 0.01, 0.008]
# rank: 0.25
#
# 15
# According to your opinion, Is Police active in your area in a positive way, active in a negative way, neither positive nor negative, not active at all?
# [1, 5, 4, 2]
# [5.0, 5.0, 25.0, 5.0]
# max: 5
# multiplier: 0.2
# multi: [0.002, 0.01, 0.008, 0.004]
# rank: 0.28
#
# 15
# According to your opinion, how available are these services and products in your area? Education
# [2, 1, 3, 4]
# [10.0, 15.0, 10.0, 60.0]
# max: 4
# multiplier: 0.25
# multi: [0.005, 0.0025, 0.0075, 0.01]
# rank: 0.7625
#
# 15
# According to your opinion, how available are these services and products in your area? Electricity
# [2, 1, 3, 4]
# [5.0, 25.0, 20.0, 35.0]
# max: 4
# multiplier: 0.25
# multi: [0.005, 0.0025, 0.0075, 0.01]
# rank: 0.5875
#
# 15
# According to your opinion, how available are these services and products in your area? Health Care
# [2, 1, 3, 4]
# [15.0, 35.0, 15.0, 30.0]
# max: 4
# multiplier: 0.25
# multi: [0.005, 0.0025, 0.0075, 0.01]
# rank: 0.575
#
# 15
# According to your opinion, how available are these services and products in your area? Water
# [3, 4]
# [10.0, 90.0]
# max: 4
# multiplier: 0.25
# multi: [0.0075, 0.01]
# rank: 0.975
#
# 15
# Do you have internet access?
# [1, 2]
# [70.0, 30.0]
# max: 2
# multiplier: 0.5
# multi: [0.005, 0.01]
# rank: 0.65
#
# 15
# First I would like to ask you about your current situation / family situation. How would you rate it on a scale from 1 to 5?
# [5, 3]
# [15.0, 40.0]
# max: 5
# multiplier: 0.2
# multi: [0.01, 0.006000000000000001]
# rank: 0.39
#
# 15
# How do evaluate the general security situation in your area?
# [3, 4, 5]
# [25.0, 35.0, 40.0]
# max: 5
# multiplier: 0.2
# multi: [0.006000000000000001, 0.008, 0.01]
# rank: 0.8300000000000001
#
# 15
# How do you evaluate the role that EU plays in Yemen?
# [2, 3, 4, 1, 5]
# [15.0, 0.0, 0.0, 25.0, 5.0]
# max: 5
# multiplier: 0.2
# multi: [0.004, 0.006000000000000001, 0.008, 0.002, 0.01]
# rank: 0.16
#
# 15
# How do you evaluate the role that Iran plays in Yemen?
# [2, 3, 4, 1, 5]
# [0.0, 0.0, 0.0, 95.0, 0.0]
# max: 5
# multiplier: 0.2
# multi: [0.004, 0.006000000000000001, 0.008, 0.002, 0.01]
# rank: 0.19
#
# 15
# How do you evaluate the role that KSA plays in Yemen?
# [2, 3, 4, 1, 5]
# [5.0, 0.0, 20.0, 10.0, 55.0]
# max: 5
# multiplier: 0.2
# multi: [0.004, 0.006000000000000001, 0.008, 0.002, 0.01]
# rank: 0.75
#
# 15
# How do you evaluate the role that US plays in Yemen?
# [2, 3, 4, 1, 5]
# [10.0, 0.0, 0.0, 60.0, 0.0]
# max: 5
# multiplier: 0.2
# multi: [0.004, 0.006000000000000001, 0.008, 0.002, 0.01]
# rank: 0.16
#
# 15
# How much do you believe Yemen should be divided into regions?
# [5]
# [45.0]
# max: 5
# multiplier: 0.2
# multi: [0.01]
# rank: 0.45
#
# 15
# How much do you believe south Yemen should be independent?
# [2, 3, 5]
# [5.0, 5.0, 5.0]
# max: 5
# multiplier: 0.2
# multi: [0.004, 0.006000000000000001, 0.01]
# rank: 0.1
#
# 15
# I will list a number of reasons that can lead to conflict "Political Difference" (Conflicts in the neighborhood)
# [2, 3, 4, 1, 5]
# [10.0, 15.0, 10.0, 35.0, 30.0]
# max: 5
# multiplier: 0.2
# multi: [0.004, 0.006000000000000001, 0.008, 0.002, 0.01]
# rank: 0.5800000000000001
#
# 15
# I will list a number of reasons that can lead to conflict "Religious Differences" (Conflicts in the neighborhood)
# [2, 4, 1, 5]
# [15.0, 20.0, 60.0, 5.0]
# max: 5
# multiplier: 0.2
# multi: [0.004, 0.008, 0.002, 0.01]
# rank: 0.38999999999999996
#
# 15
# I will list read a number of places where conflicts take place, please let me know how often conflicts take place (Conflicts in the neighborhood)
# [2, 3, 4, 1, 5]
# [5.0, 10.0, 30.0, 30.0, 25.0]
# max: 5
# multiplier: 0.2
# multi: [0.004, 0.006000000000000001, 0.008, 0.002, 0.01]
# rank: 0.63
#
# 15
# In general, what do you think about the current situation in Yemen, is it going in the right direction or in the wrong direction?
# [1, 5, 2, 4]
# [25.0, 30.0, 5.0, 15.0]
# max: 5
# multiplier: 0.2
# multi: [0.002, 0.01, 0.004, 0.008]
# rank: 0.49
#
# 15
# On a scale ranging from 1 to 5 in which "1" means "always very unsafe" and "5" means "always very safe", how safe do you personally feel?
# [5, 1, 4, 2]
# [85.0, 5.0, 5.0, 5.0]
# max: 5
# multiplier: 0.2
# multi: [0.01, 0.002, 0.008, 0.004]
# rank: 0.92
#
# 15
# Please tell me if Adequate  shelter/housing is available or not for your family
# [1, 3, 2, 5]
# [25.0, 5.0, 20.0, 50.0]
# max: 5
# multiplier: 0.2
# multi: [0.002, 0.006000000000000001, 0.004, 0.01]
# rank: 0.66
#
# 15
# Thinking about the last year, have there been times when your family didn't have enough food for all household members?
# [1, 2]
# [95.0, 5.0]
# max: 2
# multiplier: 0.5
# multi: [0.005, 0.01]
# rank: 0.525
#
# 16
# According to your opinion, Are Political Parties active in your area in a positive way, active in a negative way, neither positive nor negative, not active at all?
# [1, 5, 4]
# [22.5, 5.0, 2.5]
# max: 5
# multiplier: 0.2
# multi: [0.002, 0.01, 0.008]
# rank: 0.115
#
# 16
# According to your opinion, Are Religious groups active in your area in a positive way, active in a negative way, neither positive nor negative, not active at all?
# [1, 5, 4]
# [12.5, 15.0, 5.0]
# max: 5
# multiplier: 0.2
# multi: [0.002, 0.01, 0.008]
# rank: 0.215
#
# 16
# According to your opinion, Are Tribal leaders active in your area in a positive way, active in a negative way, neither positive nor negative, not active at all?
# [1, 5, 2]
# [10.0, 25.0, 2.5]
# max: 5
# multiplier: 0.2
# multi: [0.002, 0.01, 0.004]
# rank: 0.28
#
# 16
# According to your opinion, Is Local Council  active in your area in a positive way, active in a negative way, neither positive nor negative, not active at all?
# [1, 5, 4]
# [12.5, 2.5, 5.0]
# max: 5
# multiplier: 0.2
# multi: [0.002, 0.01, 0.008]
# rank: 0.09
#
# 16
# According to your opinion, Is NGO/CSO active in your area in a positive way, active in a negative way, neither positive nor negative, not active at all?
# [2]
# [2.5]
# max: 2
# multiplier: 0.5
# multi: [0.01]
# rank: 0.025
#
# 16
# According to your opinion, how available are these services and products in your area? Education
# [2, 1, 3]
# [32.5, 25.0, 37.5]
# max: 3
# multiplier: 0.33333333333333337
# multi: [0.006666666666666667, 0.0033333333333333335, 0.01]
# rank: 0.675
#
# 16
# According to your opinion, how available are these services and products in your area? Electricity
# [2, 1, 3, 4]
# [7.5, 77.5, 2.5, 2.5]
# max: 4
# multiplier: 0.25
# multi: [0.005, 0.0025, 0.0075, 0.01]
# rank: 0.275
#
# 16
# According to your opinion, how available are these services and products in your area? Health Care
# [2, 1, 3]
# [17.5, 75.0, 2.5]
# max: 3
# multiplier: 0.33333333333333337
# multi: [0.006666666666666667, 0.0033333333333333335, 0.01]
# rank: 0.3916666666666667
#
# 16
# According to your opinion, how available are these services and products in your area? Water
# [2, 1, 3, 4]
# [75.0, 15.0, 5.0, 2.5]
# max: 4
# multiplier: 0.25
# multi: [0.005, 0.0025, 0.0075, 0.01]
# rank: 0.475
#
# 16
# Do you have internet access?
# [1, 2]
# [90.0, 10.0]
# max: 2
# multiplier: 0.5
# multi: [0.005, 0.01]
# rank: 0.55
#
# 16
# First I would like to ask you about your current situation / family situation. How would you rate it on a scale from 1 to 5?
# [3]
# [25.0]
# max: 3
# multiplier: 0.33333333333333337
# multi: [0.01]
# rank: 0.25
#
# 16
# How do evaluate the general security situation in your area?
# [3, 4, 5]
# [2.5, 52.5, 45.0]
# max: 5
# multiplier: 0.2
# multi: [0.006000000000000001, 0.008, 0.01]
# rank: 0.885
#
# 16
# How do you evaluate the role that EU plays in Yemen?
# [2, 3, 4, 1, 5]
# [5.0, 7.5, 0.0, 37.5, 0.0]
# max: 5
# multiplier: 0.2
# multi: [0.004, 0.006000000000000001, 0.008, 0.002, 0.01]
# rank: 0.14
#
# 16
# How do you evaluate the role that Iran plays in Yemen?
# [2, 3, 4, 1, 5]
# [0.0, 15.0, 15.0, 15.0, 5.0]
# max: 5
# multiplier: 0.2
# multi: [0.004, 0.006000000000000001, 0.008, 0.002, 0.01]
# rank: 0.29000000000000004
#
# 16
# How do you evaluate the role that KSA plays in Yemen?
# [2, 3, 4, 1, 5]
# [0.0, 0.0, 0.0, 50.0, 0.0]
# max: 5
# multiplier: 0.2
# multi: [0.004, 0.006000000000000001, 0.008, 0.002, 0.01]
# rank: 0.1
#
# 16
# How do you evaluate the role that US plays in Yemen?
# [2, 3, 4, 1, 5]
# [7.5, 0.0, 0.0, 42.5, 0.0]
# max: 5
# multiplier: 0.2
# multi: [0.004, 0.006000000000000001, 0.008, 0.002, 0.01]
# rank: 0.115
#
# 16
# How much do you believe Yemen should be divided into regions?
# [2, 3, 4]
# [27.500000000000004, 7.5, 2.5]
# max: 4
# multiplier: 0.25
# multi: [0.005, 0.0075, 0.01]
# rank: 0.21875
#
# 16
# How much do you believe south Yemen should be independent?
# [2, 3, 4]
# [35.0, 7.5, 2.5]
# max: 4
# multiplier: 0.25
# ...
# rank: 0.18333333333333332
#
# 7
# How much do you believe south Yemen should be independent?
# [2, 3, 4, 5]
# [18.333333333333332, 19.166666666666668, 5.833333333333333, 3.3333333333333335]
# max: 5
# multiplier: 0.2
# multi: [0.004, 0.006000000000000001, 0.008, 0.01]
# rank: 0.26833333333333337
#
# 7
# I will list a number of reasons that can lead to conflict "Political Difference" (Conflicts in the neighborhood)
# [2, 3, 4, 1, 5]
# [25.0, 14.166666666666666, 11.666666666666666, 18.333333333333332, 30.0]
# max: 5
# multiplier: 0.2
# multi: [0.004, 0.006000000000000001, 0.008, 0.002, 0.01]
# rank: 0.615
#
# 7
# I will list a number of reasons that can lead to conflict "Religious Differences" (Conflicts in the neighborhood)
# [2, 3, 4, 1, 5]
# [26.666666666666668, 27.500000000000004, 5.833333333333333, 35.833333333333336, 0.8333333333333334]
# max: 5
# multiplier: 0.2
# multi: [0.004, 0.006000000000000001, 0.008, 0.002, 0.01]
# rank: 0.3983333333333334
#
# 7
# I will list read a number of places where conflicts take place, please let me know how often conflicts take place (Conflicts in the neighborhood)
# [2, 3, 4, 1, 5]
# [22.5, 33.33333333333333, 30.833333333333336, 1.6666666666666667, 10.833333333333334]
# max: 5
# multiplier: 0.2
# multi: [0.004, 0.006000000000000001, 0.008, 0.002, 0.01]
# rank: 0.6483333333333334
#
# 7
# In general, what do you think about the current situation in Yemen, is it going in the right direction or in the wrong direction?
# [1, 5, 2, 4]
# [18.333333333333332, 9.166666666666666, 25.0, 20.0]
# max: 5
# multiplier: 0.2
# multi: [0.002, 0.01, 0.004, 0.008]
# rank: 0.3883333333333333
#
# 7
# On a scale ranging from 1 to 5 in which "1" means "always very unsafe" and "5" means "always very safe", how safe do you personally feel?
# [5, 1, 4, 2, 3]
# [49.166666666666664, 1.6666666666666667, 32.5, 9.166666666666666, 7.5]
# max: 5
# multiplier: 0.2
# multi: [0.01, 0.002, 0.008, 0.004, 0.006000000000000001]
# rank: 0.8366666666666667
#
# 7
# Please tell me if Adequate  shelter/housing is available or not for your family
# [4, 1, 3, 2, 5]
# [23.333333333333332, 4.166666666666666, 27.500000000000004, 24.166666666666668, 20.833333333333336]
# max: 5
# multiplier: 0.2
# multi: [0.008, 0.002, 0.006000000000000001, 0.004, 0.01]
# rank: 0.665
#
# 7
# Thinking about the last year, have there been times when your family didn't have enough food for all household members?
# [1, 2]
# [56.666666666666664, 43.333333333333336]
# max: 2
# multiplier: 0.5
# multi: [0.005, 0.01]
# rank: 0.7166666666666667
#
# 8
# According to your opinion, Are Political Parties active in your area in a positive way, active in a negative way, neither positive nor negative, not active at all?
# [1, 5, 4, 2]
# [7.0588235294117645, 1.7647058823529411, 12.941176470588237, 19.411764705882355]
# max: 5
# multiplier: 0.2
# multi: [0.002, 0.01, 0.008, 0.004]
# rank: 0.21294117647058824
#
# 8
# According to your opinion, Are Religious groups active in your area in a positive way, active in a negative way, neither positive nor negative, not active at all?
# [1, 5, 4, 2]
# [0.5882352941176471, 16.470588235294116, 7.0588235294117645, 0.5882352941176471]
# max: 5
# multiplier: 0.2
# multi: [0.002, 0.01, 0.008, 0.004]
# rank: 0.22470588235294117
#
# 8
# According to your opinion, Are Tribal leaders active in your area in a positive way, active in a negative way, neither positive nor negative, not active at all?
# [1, 5, 4, 2]
# [0.5882352941176471, 32.35294117647059, 13.529411764705882, 1.1764705882352942]
# max: 5
# multiplier: 0.2
# multi: [0.002, 0.01, 0.008, 0.004]
# rank: 0.4376470588235294
#
# 8
# According to your opinion, Is Local Council  active in your area in a positive way, active in a negative way, neither positive nor negative, not active at all?
# [1, 5, 4, 2]
# [6.470588235294119, 14.705882352941178, 17.058823529411764, 11.76470588235294]
# max: 5
# multiplier: 0.2
# multi: [0.002, 0.01, 0.008, 0.004]
# rank: 0.3435294117647059
#
# 8
# According to your opinion, Is NGO/CSO active in your area in a positive way, active in a negative way, neither positive nor negative, not active at all?
# [1, 5, 4, 2]
# [4.705882352941177, 15.88235294117647, 23.52941176470588, 1.7647058823529411]
# max: 5
# multiplier: 0.2
# multi: [0.002, 0.01, 0.008, 0.004]
# rank: 0.3635294117647059
#
# 8
# According to your opinion, Is Police active in your area in a positive way, active in a negative way, neither positive nor negative, not active at all?
# [1, 5, 4, 2]
# [4.117647058823529, 20.588235294117645, 15.294117647058824, 2.941176470588235]
# max: 5
# multiplier: 0.2
# multi: [0.002, 0.01, 0.008, 0.004]
# rank: 0.3482352941176471
#
# 8
# According to your opinion, how available are these services and products in your area? Education
# [2, 1, 3, 4]
# [22.35294117647059, 12.352941176470589, 47.647058823529406, 14.705882352941178]
# max: 4
# multiplier: 0.25
# multi: [0.005, 0.0025, 0.0075, 0.01]
# rank: 0.6470588235294118
#
# 8
# According to your opinion, how available are these services and products in your area? Electricity
# [2, 1, 3, 4]
# [5.294117647058823, 88.8235294117647, 4.705882352941177, 0.5882352941176471]
# max: 4
# multiplier: 0.25
# multi: [0.005, 0.0025, 0.0075, 0.01]
# rank: 0.28970588235294115
#
# 8
# According to your opinion, how available are these services and products in your area? Health Care
# [2, 1, 3, 4]
# [23.52941176470588, 36.470588235294116, 32.94117647058823, 3.5294117647058822]
# max: 4
# multiplier: 0.25
# multi: [0.005, 0.0025, 0.0075, 0.01]
# rank: 0.4911764705882352
#
# 8
# According to your opinion, how available are these services and products in your area? Water
# [2, 1, 3, 4]
# [25.882352941176475, 4.117647058823529, 38.82352941176471, 31.176470588235293]
# max: 4
# multiplier: 0.25
# multi: [0.005, 0.0025, 0.0075, 0.01]
# rank: 0.7426470588235294
#
# 8
# Do you have internet access?
# [1, 2]
# [88.8235294117647, 11.176470588235295]
# max: 2
# multiplier: 0.5
# multi: [0.005, 0.01]
# rank: 0.5558823529411765
#
# 8
# First I would like to ask you about your current situation / family situation. How would you rate it on a scale from 1 to 5?
# [5, 3]
# [2.3529411764705883, 28.823529411764703]
# max: 5
# multiplier: 0.2
# multi: [0.01, 0.006000000000000001]
# rank: 0.19647058823529412
#
# 8
# How do evaluate the general security situation in your area?
# [2, 3, 4, 1, 5]
# [1.7647058823529411, 2.941176470588235, 42.94117647058823, 4.705882352941177, 45.88235294117647]
# max: 5
# multiplier: 0.2
# multi: [0.004, 0.006000000000000001, 0.008, 0.002, 0.01]
# rank: 0.8364705882352941
#
# 8
# How do you evaluate the role that EU plays in Yemen?
# [2, 3, 4, 1, 5]
# [5.882352941000001, 6.470588235, 1.176470588, 8.235294117999999, 0.0]
# max: 5
# multiplier: 0.2
# multi: [0.004, 0.006000000000000001, 0.008, 0.002, 0.01]
# rank: 0.08823529411400002
#
# 8
# How do you evaluate the role that Iran plays in Yemen?
# [2, 3, 4, 1, 5]
# [2.352941176, 12.35294118, 2.352941176, 20.58823529, 0.588235294]
# max: 5
# multiplier: 0.2
# multi: [0.004, 0.006000000000000001, 0.008, 0.002, 0.01]
# rank: 0.14941176471200002
#
# 8
# How do you evaluate the role that KSA plays in Yemen?
# [2, 3, 4, 1, 5]
# [5.294117647, 1.764705882, 0.588235294, 55.29411765, 0.0]
# max: 5
# multiplier: 0.2
# multi: [0.004, 0.006000000000000001, 0.008, 0.002, 0.01]
# rank: 0.147058823532
#
# 8
# How do you evaluate the role that US plays in Yemen?
# [2, 3, 4, 1, 5]
# [6.470588235, 2.9411764710000003, 0.588235294, 48.23529412, 0.0]
# max: 5
# multiplier: 0.2
# multi: [0.004, 0.006000000000000001, 0.008, 0.002, 0.01]
# rank: 0.144705882358
#
# 8
# How much do you believe Yemen should be divided into regions?
# [2, 3, 4, 5]
# [1.7647058823529411, 5.88235294117647, 1.1764705882352942, 3.5294117647058822]
# max: 5
# multiplier: 0.2
# multi: [0.004, 0.006000000000000001, 0.008, 0.01]
# rank: 0.08705882352941177
#
# 8
# How much do you believe south Yemen should be independent?
# [2, 3, 4, 5]
# [7.0588235294117645, 4.705882352941177, 0.5882352941176471, 0.5882352941176471]
# max: 5
# multiplier: 0.2
# multi: [0.004, 0.006000000000000001, 0.008, 0.01]
# rank: 0.06705882352941177
#
# 8
# I will list a number of reasons that can lead to conflict "Political Difference" (Conflicts in the neighborhood)
# [2, 3, 4, 1, 5]
# [8.235294117647058, 34.11764705882353, 2.3529411764705883, 28.823529411764703, 5.294117647058823]
# max: 5
# multiplier: 0.2
# multi: [0.004, 0.006000000000000001, 0.008, 0.002, 0.01]
# rank: 0.3670588235294117
#
# 8
# I will list a number of reasons that can lead to conflict "Religious Differences" (Conflicts in the neighborhood)
# [2, 3, 4, 1, 5]
# [8.235294117647058, 24.11764705882353, 0.5882352941176471, 45.88235294117647, 4.705882352941177]
# max: 5
# multiplier: 0.2
# multi: [0.004, 0.006000000000000001, 0.008, 0.002, 0.01]
# rank: 0.3211764705882353
#
# 8
# I will list read a number of places where conflicts take place, please let me know how often conflicts take place (Conflicts in the neighborhood)
# [2, 3, 4, 1, 5]
# [13.529411764705882, 40.588235294117645, 7.0588235294117645, 6.470588235294119, 27.058823529411764]
# max: 5
# multiplier: 0.2
# multi: [0.004, 0.006000000000000001, 0.008, 0.002, 0.01]
# rank: 0.6376470588235295
#
# 8
# In general, what do you think about the current situation in Yemen, is it going in the right direction or in the wrong direction?
# [1, 5, 2, 4]
# [8.235294117647058, 1.7647058823529411, 13.529411764705882, 11.76470588235294]
# max: 5
# multiplier: 0.2
# multi: [0.002, 0.01, 0.004, 0.008]
# rank: 0.18235294117647058
#
# 8
# On a scale ranging from 1 to 5 in which "1" means "always very unsafe" and "5" means "always very safe", how safe do you personally feel?
# [5, 1, 4, 2, 3]
# [82.94117647058825, 4.117647058823529, 5.294117647058823, 3.5294117647058822, 3.5294117647058822]
# max: 5
# multiplier: 0.2
# multi: [0.01, 0.002, 0.008, 0.004, 0.006000000000000001]
# rank: 0.915294117647059
#
# 8
# Please tell me if Adequate  shelter/housing is available or not for your family
# [4, 1, 3, 2, 5]
# [51.17647058823529, 0.5882352941176471, 17.058823529411764, 20.588235294117645, 10.588235294117647]
# max: 5
# multiplier: 0.2
# multi: [0.008, 0.002, 0.006000000000000001, 0.004, 0.01]
# rank: 0.7011764705882353
#
# 8
# Thinking about the last year, have there been times when your family didn't have enough food for all household members?
# [1, 2]
# [62.94117647058823, 34.705882352941174]
# max: 2
# multiplier: 0.5
# multi: [0.005, 0.01]
# rank: 0.6617647058823529
#
# 9
# According to your opinion, Are Political Parties active in your area in a positive way, active in a negative way, neither positive nor negative, not active at all?
# [1, 5, 4, 2]
# [18.75, 3.75, 10.0, 13.750000000000002]
# max: 5
# multiplier: 0.2
# multi: [0.002, 0.01, 0.008, 0.004]
# rank: 0.21000000000000002
#
# 9
# According to your opinion, Are Religious groups active in your area in a positive way, active in a negative way, neither positive nor negative, not active at all?
# [5, 4]
# [23.75, 5.0]
# max: 5
# multiplier: 0.2
# multi: [0.01, 0.008]
# rank: 0.2775
#
# 9
# According to your opinion, Are Tribal leaders active in your area in a positive way, active in a negative way, neither positive nor negative, not active at all?
# [1, 5]
# [2.5, 12.5]
# max: 5
# multiplier: 0.2
# multi: [0.002, 0.01]
# rank: 0.13
#
# 9
# According to your opinion, Is Local Council  active in your area in a positive way, active in a negative way, neither positive nor negative, not active at all?
# [1, 5, 4, 2]
# [7.5, 18.75, 10.0, 7.5]
# max: 5
# multiplier: 0.2
# multi: [0.002, 0.01, 0.008, 0.004]
# rank: 0.3125
#
# 9
# According to your opinion, Is NGO/CSO active in your area in a positive way, active in a negative way, neither positive nor negative, not active at all?
# [1, 5, 4, 2]
# [1.25, 13.750000000000002, 1.25, 2.5]
# max: 5
# multiplier: 0.2
# multi: [0.002, 0.01, 0.008, 0.004]
# rank: 0.16000000000000003
#
# 9
# According to your opinion, Is Police active in your area in a positive way, active in a negative way, neither positive nor negative, not active at all?
# [1, 5, 4, 2]
# [11.25, 32.5, 18.75, 3.75]
# max: 5
# multiplier: 0.2
# multi: [0.002, 0.01, 0.008, 0.004]
# rank: 0.5125000000000001
#
# 9
# According to your opinion, how available are these services and products in your area? Education
# [2, 3, 4]
# [7.5, 32.5, 60.0]
# max: 4
# multiplier: 0.25
# multi: [0.005, 0.0075, 0.01]
# rank: 0.88125
#
# 9
# According to your opinion, how available are these services and products in your area? Electricity
# [2, 3, 4]
# [7.5, 42.5, 50.0]
# max: 4
# multiplier: 0.25
# multi: [0.005, 0.0075, 0.01]
# rank: 0.85625
#
# 9
# According to your opinion, how available are these services and products in your area? Health Care
# [2, 3, 4]
# [10.0, 31.25, 58.75]
# max: 4
# multiplier: 0.25
# multi: [0.005, 0.0075, 0.01]
# rank: 0.871875
#
# 9
# According to your opinion, how available are these services and products in your area? Water
# [2, 3, 4]
# [1.25, 41.25, 57.49999999999999]
# max: 4
# multiplier: 0.25
# multi: [0.005, 0.0075, 0.01]
# rank: 0.890625
#
# 9
# Do you have internet access?
# [1, 2]
# [65.0, 32.5]
# max: 2
# multiplier: 0.5
# multi: [0.005, 0.01]
# rank: 0.65
#
# 9
# First I would like to ask you about your current situation / family situation. How would you rate it on a scale from 1 to 5?
# [5, 3]
# [8.75, 21.25]
# max: 5
# multiplier: 0.2
# multi: [0.01, 0.006000000000000001]
# rank: 0.21500000000000002
#
# 9
# How do evaluate the general security situation in your area?
# [3, 4, 5]
# [7.5, 51.24999999999999, 41.25]
# max: 5
# multiplier: 0.2
# multi: [0.006000000000000001, 0.008, 0.01]
# rank: 0.8674999999999999
#
# 9
# How do you evaluate the role that EU plays in Yemen?
# [2, 3, 4, 1, 5]
# [2.5, 11.25, 1.25, 15.0, 0.0]
# max: 5
# multiplier: 0.2
# multi: [0.004, 0.006000000000000001, 0.008, 0.002, 0.01]
# rank: 0.1175
#
# 9
# How do you evaluate the role that Iran plays in Yemen?
# [2, 3, 4, 1, 5]
# [1.25, 6.25, 1.25, 35.0, 0.0]
# max: 5
# multiplier: 0.2
# multi: [0.004, 0.006000000000000001, 0.008, 0.002, 0.01]
# rank: 0.12250000000000001
#
# 9
# How do you evaluate the role that KSA plays in Yemen?
# [2, 3, 4, 1, 5]
# [1.25, 7.5, 18.75, 1.25, 37.5]
# max: 5
# multiplier: 0.2
# multi: [0.004, 0.006000000000000001, 0.008, 0.002, 0.01]
# rank: 0.5775
#
# 9
# How do you evaluate the role that US plays in Yemen?
# [2, 3, 4, 1, 5]
# [7.5, 3.75, 1.25, 30.0, 0.0]
# max: 5
# multiplier: 0.2
# multi: [0.004, 0.006000000000000001, 0.008, 0.002, 0.01]
# rank: 0.1225
#
# 9
# How much do you believe Yemen should be divided into regions?
# [2, 3, 4, 5]
# [7.5, 10.0, 3.75, 16.25]
# max: 5
# multiplier: 0.2
# multi: [0.004, 0.006000000000000001, 0.008, 0.01]
# rank: 0.28250000000000003
#
# 9
# How much do you believe south Yemen should be independent?
# [3, 4, 5]
# [12.5, 8.75, 36.25]
# max: 5
# multiplier: 0.2
# multi: [0.006000000000000001, 0.008, 0.01]
# rank: 0.5075000000000001
#
# 9
# I will list a number of reasons that can lead to conflict "Political Difference" (Conflicts in the neighborhood)
# [2, 3, 1]
# [13.750000000000002, 20.0, 46.25]
# max: 3
# multiplier: 0.33333333333333337
# multi: [0.006666666666666667, 0.01, 0.0033333333333333335]
# rank: 0.44583333333333336
#
# 9
# I will list a number of reasons that can lead to conflict "Religious Differences" (Conflicts in the neighborhood)
# [2, 3, 4, 1, 5]
# [7.5, 23.75, 1.25, 46.25, 1.25]
# max: 5
# multiplier: 0.2
# multi: [0.004, 0.006000000000000001, 0.008, 0.002, 0.01]
# rank: 0.28750000000000003
#
# 9
# I will list read a number of places where conflicts take place, please let me know how often conflicts take place (Conflicts in the neighborhood)
# [2, 3, 4, 1, 5]
# [13.750000000000002, 42.5, 13.750000000000002, 10.0, 3.75]
# max: 5
# multiplier: 0.2
# multi: [0.004, 0.006000000000000001, 0.008, 0.002, 0.01]
# rank: 0.47750000000000004
#
# 9
# In general, what do you think about the current situation in Yemen, is it going in the right direction or in the wrong direction?
# [5, 2, 4]
# [10.0, 20.0, 36.25]
# max: 5
# multiplier: 0.2
# multi: [0.01, 0.004, 0.008]
# rank: 0.47
#
# 9
# On a scale ranging from 1 to 5 in which "1" means "always very unsafe" and "5" means "always very safe", how safe do you personally feel?
# [5, 4, 2, 3]
# [82.5, 12.5, 1.25, 2.5]
# max: 5
# multiplier: 0.2
# multi: [0.01, 0.008, 0.004, 0.006000000000000001]
# rank: 0.9450000000000001
#
# 9
# Please tell me if Adequate  shelter/housing is available or not for your family
# [4, 1, 3, 2, 5]
# [13.750000000000002, 2.5, 22.5, 6.25, 55.00000000000001]
# max: 5
# multiplier: 0.2
# multi: [0.008, 0.002, 0.006000000000000001, 0.004, 0.01]
# rank: 0.8250000000000001
#
# 9
# Thinking about the last year, have there been times when your family didn't have enough food for all household members?
# [1, 2]
# [91.25, 8.75]
# max: 2
# multiplier: 0.5
# multi: [0.005, 0.01]
# rank: 0.54375
